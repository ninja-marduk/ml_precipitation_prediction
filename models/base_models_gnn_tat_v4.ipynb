# %% [markdown]
# <a href="https://colab.research.google.com/github/ninja-marduk/ml_precipitation_prediction/blob/main/models/base_models_gnn_tat_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================
# NOTEBOOK VERSION  (edit this block whenever the notebook changes)
# =============================================================
NOTEBOOK_VERSION = 'v4.23'
NOTEBOOK_DATE    = '2026-08-19'

# -------------------------------------------------------------
# WHICH RUN IS THIS?  One name sets the seeds, the feature bundles,
# the variants and the ablation together, so they cannot drift apart.
# v4.11 shipped a new mode but left the selector pointing at the
# previous one, and repeated a five-hour run.
# -------------------------------------------------------------
RUN_PLAN = 'factorial_p30_456_pafc'

_PLANS = {
    # Seven new seeds on GAT + BASIC, the configuration the headline and the
    # late-fusion comparison both rest on. Takes that cell from n=3 to n=10,
    # which is what every reviewer of the manuscript asked for: at n=3 the
    # minimum detectable effect is about 0.052 R2, larger than every effect
    # the paper discusses. About 12 h. SKIP_EXISTING protects 42/123/456.
    'seeds10_headline': dict(
        ablation=None, seeds=[789, 1011, 1213, 1415, 1617, 1819, 2021],
        features=['BASIC'], variants=['GAT'], skip_existing=True),

    # The paper's factorial, all of it, under one protocol. Six cells
    # (BASIC and PAFC x GAT, GCN and SAGE) on three seeds. GAT+BASIC is
    # included even though it exists, because this plan raises the early-
    # stopping patience to 30 and a cell trained under a different stopping
    # rule is not comparable with the rest.
    #
    # Why 30. Across the twelve archived runs at patience ~50 the best epoch
    # was 7 or earlier in ten of them, 25 in one (GAT+PAFC) and 100 in one
    # (KCE, not in this factorial). Patience 15, which the completed runs
    # used, would very likely have stopped before epoch 25 and biased the
    # comparison against PAFC, which is the bundle the ranking claim turns on.
    # 30 covers the observed worst case in this factorial with room to spare.
    #
    # Cost, from the measured 321.7 s/epoch and 27.05 GB on an A100-SXM4-80GB:
    # about 59 A100-hours as an upper bound (that rate is GAT's; GCN and SAGE
    # carry no multi-head attention over edges and will come in under it).
    # Expected epochs per cell, best_epoch + 31: GAT/BASIC 35, GAT/PAFC 47,
    # GCN/BASIC 33, GCN/PAFC 36, SAGE/BASIC 34, SAGE/PAFC 34.
    #
    # Writes to V4_GNN_TAT_Models_p30. It must not write to the production
    # tree: the manuscript, the fusion decomposition, the stratified tables,
    # the spatial maps and the anomaly analysis all read the seed-scoped
    # arrays there, and overwriting them would change published numbers as a
    # side effect of a training job. Compare first, adopt deliberately.
    'factorial_p30': dict(
        ablation=None, seeds=[42, 123, 456],
        features=['BASIC', 'PAFC'], variants=['GAT', 'GCN', 'SAGE'],
        skip_existing=True, config_overrides={'patience': 30},
        out_suffix='p30'),

    # Same plan on a 5x5 grid for two epochs: 25 nodes instead of 3,965.
    # It exercises plan resolution, the config overrides, the output tree,
    # the variant and bundle loop, training, the exports and the metric
    # files, in minutes. What it cannot check is anything that depends on
    # the real graph: at 25 nodes there are 300 possible edges, so the
    # 500,000 budget never binds and peak memory is nothing like the 27 GB
    # of a full run. Use it to find a broken path, not to predict a cost.
    'smoke_p30': dict(
        ablation=None, seeds=[42], features=['BASIC', 'PAFC'],
        variants=['GAT', 'GCN', 'SAGE'], skip_existing=False,
        config_overrides={'patience': 30, 'light_mode': True, 'epochs': 2},
        out_suffix='smoke'),

    # The twelve cells the corrected graph never got. The factorial is
    # 3 seeds x 3 bundles x 3 variants = 27; fifteen exist, so this fills the
    # rest and lets the feature-bundle claim stop resting on the archived
    # leaked-graph run. About 20 h. Order the plans this way, not the reverse.
    'factorial_fill': dict(
        ablation=None, seeds=[42, 123, 456],
        features=['BASIC', 'KCE', 'PAFC'], variants=['GAT', 'GCN', 'SAGE'],
        skip_existing=True),

    # Exactly the released configuration. Only for rebuilding a tree from
    # scratch; with SKIP_EXISTING it is a no-op against the current outputs.
    'production': dict(
        ablation=None, seeds=[42, 123, 456],
        features=['BASIC'], variants=['GAT'], skip_existing=True),

    # Diagnostics. Each writes to its own out_root and must never be reported
    # as model performance.
    'ablation_leaked_graph': dict(
        ablation='leaked_graph', seeds=[42, 123, 456],
        features=['BASIC'], variants=['GAT'], skip_existing=False),
    'ablation_batch2': dict(
        ablation='batch2', seeds=[42, 123, 456],
        features=['BASIC'], variants=['GAT'], skip_existing=False),
    'ablation_no_tf32': dict(
        ablation='no_tf32', seeds=[42, 123, 456],
        features=['BASIC'], variants=['GAT'], skip_existing=False),

    # Use whatever CONFIG and SEEDS already say. For interactive work only.
    'manual': None,
}

# Chunks of factorial_p30, because 59 hours does not fit a Colab session. Each is
# one seed and one bundle across the three variants: about 9 h for a BASIC chunk
# and 10.4 h for a PAFC one, and a coherent unit, since a chunk either completes a
# (seed, bundle) row of the factorial or visibly does not. They share the p30
# output tree and skip what is already finished, so a chunk can be rerun after a
# dropped session without repeating work.
for _s in (42, 123, 456):
    for _b in ('BASIC', 'PAFC'):
        _PLANS[f'factorial_p30_{_s}_{_b.lower()}'] = dict(
            ablation=None, seeds=[_s], features=[_b],
            variants=['GAT', 'GCN', 'SAGE'], skip_existing=True,
            config_overrides={'patience': 30}, out_suffix='p30')

        # A light twin of each chunk, differing only in the grid and the epoch
        # cap, so the rehearsal has the same shape as the run it precedes. It
        # never skips: a smoke test that silently does nothing is worse than no
        # smoke test. Writes to the smoke tree, which nothing else reads.
        _PLANS[f'smoke_p30_{_s}_{_b.lower()}'] = dict(
            ablation=None, seeds=[_s], features=[_b],
            variants=['GAT', 'GCN', 'SAGE'], skip_existing=False,
            config_overrides={'patience': 30, 'light_mode': True, 'epochs': 2},
            out_suffix='smoke')

if RUN_PLAN not in _PLANS:
    raise ValueError(f"RUN_PLAN must be one of {sorted(_PLANS)}, got {RUN_PLAN!r}")

_plan = _PLANS[RUN_PLAN]
ABLATION = _plan['ablation'] if _plan else None
if _plan:
    PLAN_SEEDS = list(_plan['seeds'])
    PLAN_FEATURES = list(_plan['features'])
    PLAN_VARIANTS = list(_plan['variants'])
    PLAN_SKIP_EXISTING = bool(_plan['skip_existing'])
    # Optional. A plan that changes a CONFIG setting or the output tree says so
    # here and the banner prints it, so a run cannot be described by a name that
    # does not mention what it changed.
    PLAN_CONFIG = dict(_plan.get('config_overrides') or {})
    PLAN_OUT_SUFFIX = _plan.get('out_suffix')

CHANGELOG = [
    "v4.23 last chunk: factorial_p30_456_pafc closes the eighteen cells; BASIC is complete and resolves nothing",
    "v4.22 selector on factorial_p30_456_basic; twelve cells done and the six-cell ranking reverses between the two seeds run so far",
    "v4.21 selector on factorial_p30_123_basic; patience stays 30 though every cell peaks by epoch 5, because a factorial that changes a knob halfway mixes protocols",
    "v4.20 selector on factorial_p30_123_pafc: the one archived cell that peaked at epoch 25, so it decides whether patience 30 was worth buying",
    "v4.19 selector on factorial_p30_42_pafc; measured rates from the BASIC chunk put it near 4.4 h, not 10.4",
    "v4.18 selector on factorial_p30_42_basic: first full chunk, ~9 h, expect chunk 30 and ~27 GB",
    "v4.17 the probe model reads CONFIG for the chunk size; it announced a value the trained models did not use",
    "v4.16 each chunk gets a light twin (smoke_p30_<seed>_<bundle>); selector starts on smoke_p30_42_basic",
    "v4.15 plan overrides generalised to config_overrides; smoke_p30 (5x5, 2 epochs) and six chunk plans",
    "v4.14 RUN_PLAN can set patience and out_suffix; lr_patience decoupled so raising one does not move the scheduler",
    "v4.13 RUN_PLAN drives seeds, bundles, variants and ablation from one name; seeds10_headline takes GAT+BASIC to n=10",
    "v4.12 ABLATION declared in cell 1 and echoed in the banner; v4.11 repeated batch2 because it was not moved",
    "v4.11 ABLATION 'no_tf32': last systematic difference from the archived run; batch2 tested and ruled out",
    "v4.10 ABLATION is now a mode: None | 'leaked_graph' | 'batch2'; leakage measured at -0.002 R2 (nil)",
    'v4.9  ABLATION_LEAKED_GRAPH replaces v4.8: the thresholded graph is dense (15.7M), so removing the budget OOMs',
    'v4.8  ABLATION_FULL_EDGE_SET: withdrawn, premise was wrong (assumed ~1M edges, actual 15.7M)',
    'v4.7  max_edges is an explicit CONFIG hyperparameter, always applied; sparse conversion vectorised',
    'v4.6  throughput: GPU-resident tensors, cached batched edges, chunk 30, TF32, per-epoch timing',
    'v4.5  chunk 15 (80GB A100) and patience 15: ~7x fewer GNN iterations, stops overfitting runs early',
    'v4.4  gradient checkpointing on GNN chunks (chunking alone did not cap memory)',
    'v4.3  pass gnn_chunk_size at ALL THREE GNN_TAT construction sites (fixes CUDA OOM)',
    'v4.2  gnn_chunk_size added to CONFIG (default 2); SKIP_EXISTING = False so reruns retrain',
    'v4.1  graph correlation edges estimated on the TRAINING period only (leakage fix)',
    'v4.0  baseline',
]

print('=' * 62)
print(f'NOTEBOOK {NOTEBOOK_VERSION}   ({NOTEBOOK_DATE})')
print('=' * 62)
for _c in CHANGELOG:
    print('  ' + _c)
print('=' * 62)
print('Expected during training:  GNN chunk size: 30 timesteps')
print('Expected during graph build: edge budget applied -> 500,000 edges')
print('=' * 62)
print(f'RUN_PLAN: {RUN_PLAN!r}')
if _plan:
    print(f'  seeds    : {PLAN_SEEDS}')
    print(f'  bundles  : {PLAN_FEATURES}')
    print(f'  variants : {PLAN_VARIANTS}')
    print(f'  skip done: {PLAN_SKIP_EXISTING}')
    for _k, _v in sorted(PLAN_CONFIG.items()):
        print(f'  override : CONFIG[{_k!r}] = {_v!r}')
    if PLAN_OUT_SUFFIX:
        print(f'  out tree : V4_GNN_TAT_Models_{PLAN_OUT_SUFFIX}'
              f'  (production tree untouched)')
    print(f'  cells this run: {len(PLAN_SEEDS) * len(PLAN_FEATURES) * len(PLAN_VARIANTS)}'
          f' before SKIP_EXISTING removes the ones already on disk')
else:
    print('  manual: CONFIG and SEEDS are used as written')
_banner_tree = ('V4_GNN_TAT_Models_' + PLAN_OUT_SUFFIX) if (_plan and PLAN_OUT_SUFFIX) \
    else 'V4_GNN_TAT_Models'
if ABLATION is None:
    print(f'  ablation : none, this is a production run -> {_banner_tree}')
else:
    print(f'  ablation : {ABLATION!r} -> V4_GNN_TAT_Models_{ABLATION}')
    print('             Diagnostic. These numbers are never model performance.')
print('Expected in the epoch line: s/ep, ETA and peak GPU memory')
print('If you see chunk size 2 or 15, Colab loaded an OLD copy. Stop and reload.')
print('=' * 62)
# Out:
# ...
# NOTEBOOK v4.23   (2026-08-19)
# ...
#   v4.23 last chunk: factorial_p30_456_pafc closes the eighteen cells; BASIC is complete and resolves nothing
#   v4.22 selector on factorial_p30_456_basic; twelve cells done and the six-cell ranking reverses between the two seeds run so far
#   v4.21 selector on factorial_p30_123_basic; patience stays 30 though every cell peaks by epoch 5, because a factorial that changes a knob halfway mixes protocols
#   v4.20 selector on factorial_p30_123_pafc: the one archived cell that peaked at epoch 25, so it decides whether patience 30 was worth buying
#   v4.19 selector on factorial_p30_42_pafc; measured rates from the BASIC chunk put it near 4.4 h, not 10.4
#   v4.18 selector on factorial_p30_42_basic: first full chunk, ~9 h, expect chunk 30 and ~27 GB
#   v4.17 the probe model reads CONFIG for the chunk size; it announced a value the trained models did not use
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/ninja-marduk/ml_precipitation_prediction/blob/main/models/base_models_gnn_tat_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # V4 GNN-TAT: Graph Neural Networks + Temporal Attention for Spatiotemporal Precipitation Prediction
#
# ## STHyMOUNTAIN Framework - Version 4
#
# **Author:** Manuel R. Pérez
# **Date:** January 2026
# **Institution:** UPTC - Pedagogical and Technological University of Colombia
#
# ---
#
# ### Innovation Summary
#
# This notebook implements **Graph Neural Networks with Temporal Attention (GNN-TAT)** for monthly precipitation prediction. Key innovations:
#
# 1. **Spatial Graph Representation**: Model grid cells as nodes with edges based on:
#    - Geographic distance (inverse weighting)
#    - Elevation similarity (orographic effects)
#    - Historical precipitation correlation
#
# 2. **GNN Encoder**: GraphSAGE/GAT architecture to capture non-Euclidean spatial dependencies
#
# 3. **Temporal Attention**: Multi-head attention over the temporal sequence (60 months)
#
# 4. **LSTM Decoder**: Sequence-to-sequence prediction with horizon output
#
# ### Why GNN-TAT?
#
# - ConvLSTM assumes regular Euclidean grid → fails to capture orographic effects in mountains
# - GNN captures non-Euclidean dependencies via learned edge weights
# - Temporal attention allows focus on relevant historical patterns
# - Interpretable: edge weights reveal spatial dependencies
#
# ### Contribution Target
#
# - **Paper**: Nature Communications / Water Resources Research (Q1)
# - **Novelty**: First GNN for monthly precipitation prediction on grid data
#
# ---
#
# **Version History:**
# - V4.0 (Jan 2026): Initial GNN-TAT implementation

# %% [markdown]
# ## 1. Environment Setup and Imports

# %%
# =============================================================================
# CELL 1: Environment Detection and Package Installation
# =============================================================================

import os
import sys
import shutil

# Detect environment
IN_COLAB = 'google.colab' in sys.modules

# Version info from local machine where dataset was created
LOCAL_VERSIONS = {
    'netCDF4': '1.7.2',
    'h5py': '3.14.0',
    'HDF5_lib': '1.14.4',
    'netCDF_lib': '4.9.2'
}

if IN_COLAB:
    print("Running in Google Colab")
    from google.colab import drive
    drive.mount('/content/drive')

    # Install PyTorch Geometric - FAST method
    import subprocess

    subprocess.run([
        sys.executable, '-m', 'pip', 'install',
        'torch-geometric', '-q'
    ], check=True)

    # Install specific versions matching local environment to avoid HDF5 incompatibility
    # MODIFICATION: Remove explicit version pinning for netCDF4 and h5py
    #               to allow pip to find compatible versions with Colab's HDF5 lib.
    #               Also, ensure h5netcdf is installed for open_dataset engine.
    subprocess.run([
        sys.executable, '-m', 'pip', 'install',
        "netcdf4", # Removed specific version
        "h5py",    # Removed specific version
        'xarray', 'h5netcdf', '-q'
    ], check=True)

    # Check installed versions and warn if different
    import netCDF4
    import h5py

    print(f"\nVersion check:")
    print(f"  netCDF4: {netCDF4.__version__} (local: {LOCAL_VERSIONS['netCDF4']})")
    print(f"  h5py: {h5py.__version__} (local: {LOCAL_VERSIONS['h5py']})")
    # Check if HDF5_lib_version exists, sometimes it might not be directly available or named differently
    hdf5_lib_version = getattr(netCDF4, '__hdf5libversion__', 'N/A')
    netcdf_lib_version = getattr(netCDF4, '__netcdf4libversion__', 'N/A')

    print(f"  HDF5 lib: {hdf5_lib_version} (local: {LOCAL_VERSIONS['HDF5_lib']})")
    print(f"  netCDF lib: {netcdf_lib_version} (local: {LOCAL_VERSIONS['netCDF_lib']})")

    # Warn about version mismatches
    if netCDF4.__version__ != LOCAL_VERSIONS['netCDF4']:
        print(f"  WARNING: netCDF4 version mismatch!")
    if hdf5_lib_version != LOCAL_VERSIONS['HDF5_lib']:
        print(f"  WARNING: HDF5 library version mismatch - may cause read errors! Current: {hdf5_lib_version}, Expected: {LOCAL_VERSIONS['HDF5_lib']} ")

    BASE_PATH = '/content/drive/MyDrive/ml_precipitation_prediction'

    # Copy dataset to local disk for faster access
    DRIVE_DATA_FILE = f"{BASE_PATH}/data/output/complete_dataset_with_features_with_clusters_elevation_windows_imfs_with_onehot_elevation_clean.nc"
    LOCAL_DATA_FILE = '/content/dataset_local.nc'

    if os.path.exists(DRIVE_DATA_FILE):
        if os.path.exists(LOCAL_DATA_FILE):
            print(f"\nRemoving existing local dataset: {LOCAL_DATA_FILE}")
            os.remove(LOCAL_DATA_FILE) # MODIFICATION: Remove existing local file to ensure a fresh copy
            print("  Removed!")

        print(f"\nCopying dataset to local disk...")
        shutil.copy(DRIVE_DATA_FILE, LOCAL_DATA_FILE)
        print("  Copy completed!")
        USE_LOCAL_DATA = True
    else:
        print(f"WARNING: Dataset not found: {DRIVE_DATA_FILE}")
        USE_LOCAL_DATA = False
else:
    print("Running locally")
    BASE_PATH = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
    if not BASE_PATH or BASE_PATH == '':
        BASE_PATH = r'd:\github.com\ninja-marduk\ml_precipitation_prediction'
    USE_LOCAL_DATA = False
    LOCAL_DATA_FILE = None

print(f"\nBase path: {BASE_PATH}")

if BASE_PATH not in sys.path:
    sys.path.insert(0, BASE_PATH)

print("Installation complete!")
# Out:
# Running in Google Colab
# Mounted at /content/drive
#
# Version check:
#   netCDF4: 1.7.4 (local: 1.7.2)
#   h5py: 3.16.0 (local: 3.14.0)
#   HDF5 lib: 1.14.6 (local: 1.14.4)
#   netCDF lib: 4.9.3 (local: 4.9.2)
#   WARNING: netCDF4 version mismatch!
#   WARNING: HDF5 library version mismatch - may cause read errors! Current: 1.14.6, Expected: 1.14.4
#
# Copying dataset to local disk...
#   Copy completed!
#
# Base path: /content/drive/MyDrive/ml_precipitation_prediction
# Installation complete!

# %%
# =============================================================================
# CELL 2: Core Imports
# =============================================================================

# Disable TF oneDNN warnings before importing
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Must be set before the first CUDA allocation. Lets the caching allocator grow a
# segment instead of fragmenting, which is what turns a large GNN chunk into an OOM.
os.environ.setdefault('PYTORCH_CUDA_ALLOC_CONF', 'expandable_segments:True')

import warnings
warnings.filterwarnings('ignore')

# Core scientific computing
import numpy as np
import pandas as pd
import xarray as xr
from pathlib import Path

# PyTorch and PyTorch Geometric for GNN
import torch
import torch.utils.checkpoint  # explicit: needed for gradient checkpointing
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# PyTorch Geometric
try:
    import torch_geometric
    from torch_geometric.nn import GCNConv, GATConv, SAGEConv, global_mean_pool
    from torch_geometric.data import Data, Batch
    from torch_geometric.utils import dense_to_sparse, to_dense_adj
    TORCH_GEOMETRIC_AVAILABLE = True
    print(f"PyTorch Geometric version: {torch_geometric.__version__}")
except ImportError:
    TORCH_GEOMETRIC_AVAILABLE = False
    print("WARNING: PyTorch Geometric not available. Install with pip install torch-geometric")

# TensorFlow for compatibility with existing pipeline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L
from tensorflow.keras.callbacks import Callback, CSVLogger, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

# Preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr

# Utilities
import gc
import json
import time
import logging
from datetime import datetime
from typing import Dict, List, Tuple, Optional, Union
from collections import defaultdict

# Visualization
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.gridspec import GridSpec

try:
    import geopandas as gpd
    GEOPANDAS_AVAILABLE = True
except ImportError:
    GEOPANDAS_AVAILABLE = False

try:
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature
    CARTOPY_AVAILABLE = True
except ImportError:
    CARTOPY_AVAILABLE = False

try:
    import imageio.v2 as imageio
    IMAGEIO_AVAILABLE = True
except ImportError:
    IMAGEIO_AVAILABLE = False

# Print versions
print(f"\nEnvironment Summary:")
print(f"  PyTorch: {torch.__version__}")
print(f"  TensorFlow: {tf.__version__}")
print(f"  NumPy: {np.__version__}")
print(f"  CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"  CUDA device: {torch.cuda.get_device_name(0)}")
    _prop = torch.cuda.get_device_properties(0)
    print(f"  CUDA memory: {_prop.total_memory / 1e9:.1f} GB, {_prop.multi_processor_count} SMs")

    # Ampere tensor cores for fp32 matmuls. Reduces the mantissa of the matmul
    # accumulation, not of the stored tensors; standard practice on A100 and
    # reported in the compute section.
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
    torch.backends.cudnn.benchmark = True
    print("  TF32 matmul: enabled")
# Out:
# PyTorch Geometric version: 2.8.0.post1
#
# Environment Summary:
#   PyTorch: 2.11.0+cu128
#   TensorFlow: 2.20.0
#   NumPy: 2.1.3
#   CUDA available: True
#   CUDA device: NVIDIA A100-SXM4-40GB
#   CUDA memory: 42.4 GB, 108 SMs
#   TF32 matmul: enabled

# %% [markdown]
# ## 2. Configuration

# %%
# =============================================================================
# CELL 3: Configuration Dictionary (V2/V3 Compatible) - OPTIMIZED
# =============================================================================
# Changes: Added parametrized graph construction values, reduced num_gnn_layers

CONFIG = {
    # -------------------------------------------------------------------------
    # Data and Paths
    # -------------------------------------------------------------------------
    'input_window': 60,           # Number of historical months
    'horizon': 12,                # Prediction horizon (months ahead)
    'base_path': Path(BASE_PATH),
    'data_file': None,            # Auto-set below
    'out_root': None,             # Auto-set below

    # -------------------------------------------------------------------------
    # Model Training
    # -------------------------------------------------------------------------
    'epochs': 150,
    'batch_size': 4,              # 4 fits an 80GB A100 at chunk 30; raising it changes the
                                  # optimisation trajectory, so it is a reported hyperparameter
    'learning_rate': 1e-3,
    'patience': 15,               # early stopping, in epochs without improvement. A run plan
                                  # may raise it (factorial_p30 uses 30); the value actually
                                  # used is printed in the banner and recorded per run.
    'lr_patience': 7,             # ReduceLROnPlateau patience, pinned rather than derived from
                                  # the early-stopping patience. It used to be patience // 2, so
                                  # waiting longer before stopping also changed the learning-rate
                                  # schedule, which makes two runs incomparable for a reason that
                                  # has nothing to do with stopping.
    'gradient_accumulation_steps': 1,
    'gnn_chunk_size': 30,          # timesteps per GNN propagate. Peak memory scales with this,
                                   # runtime scales inversely (fewer, larger kernels). 30 lands
                                   # near 25 GB on an 80 GB A100; raise to 60 only after the
                                   # epoch line reports peak GPU memory below ~35 GB.
    'gnn_grad_checkpoint': True,   # recompute chunk activations in backward (big memory saving)
    'prediction_batch_size': 8,    # inference only (no autograd graph), so it can exceed batch_size
    'weight_decay': 1e-5,         # L2 regularization for GNN

    # -------------------------------------------------------------------------
    # Data Handling
    # -------------------------------------------------------------------------
    'gpu_resident_data': True,     # hold X/y on the GPU instead of staging every batch over PCIe.
                                   # Falls back to host staging automatically if it would not fit.
    'use_amp': False,              # bf16 autocast. ~1.5x faster but changes numerics: validate on one
                                   # config against the fp32 val_loss before adopting it for all seeds.
    'amp_dtype': 'bf16',

    'train_val_split': 0.8,
    'light_mode': False,           # Subset for quick testing
    'light_grid_size': 5,         # 5x5 pixel subset (25 nodes for GNN)
    'loss_weighting': 'uniform',
    'save_window_metrics': False,

    # -------------------------------------------------------------------------
    # Horizons to Run
    # -------------------------------------------------------------------------
    'enabled_horizons': [12],     # Can be [3, 6, 12] for multi-horizon

    # -------------------------------------------------------------------------
    # Feature Sets (V2/V3 Compatible)
    # -------------------------------------------------------------------------
    'feature_sets': {
        'BASIC': [
            'year', 'month', 'month_sin', 'month_cos', 'doy_sin', 'doy_cos',
            'max_daily_precipitation', 'min_daily_precipitation', 'daily_precipitation_std',
            'elevation', 'slope', 'aspect'
        ],
        'KCE': [
            'year', 'month', 'month_sin', 'month_cos', 'doy_sin', 'doy_cos',
            'max_daily_precipitation', 'min_daily_precipitation', 'daily_precipitation_std',
            'elevation', 'slope', 'aspect', 'elev_high', 'elev_med', 'elev_low'
        ],
        'PAFC': [
            'year', 'month', 'month_sin', 'month_cos', 'doy_sin', 'doy_cos',
            'max_daily_precipitation', 'min_daily_precipitation', 'daily_precipitation_std',
            'elevation', 'slope', 'aspect', 'elev_high', 'elev_med', 'elev_low',
            'total_precipitation_lag1', 'total_precipitation_lag2', 'total_precipitation_lag12'
        ]
    },

    # -------------------------------------------------------------------------
    # Factorial filters (feature x variant)
    # PATCH: factorial (enabled_variants x enabled_features)
    # 'enabled_variants' : list of GNN variants to train (subset of ['GAT','GCN','SAGE']).
    #                     Defaults to ['GAT'] for backward compatibility with the
    #                     original Paper 5 filter.
    # 'enabled_features' : list of feature bundles to run (subset of feature_sets keys).
    #                     Defaults to all three. Set to a subset to run only a subset
    #                     of the factorial grid.
    # -------------------------------------------------------------------------
    'enabled_variants': list(PLAN_VARIANTS) if _plan else ['GAT'],     # RUN_PLAN, cell 1
    'enabled_features': list(PLAN_FEATURES) if _plan else ['BASIC'],   # RUN_PLAN, cell 1

    # -------------------------------------------------------------------------
    # GNN-TAT Specific Configuration
    # -------------------------------------------------------------------------
    'gnn_config': {
        'hidden_dim': 64,              # GNN hidden dimension
        'num_gnn_layers': 2,           # Number of GNN layers (reduced from 3)
        'gnn_type': 'GAT',             # 'GAT', 'SAGE', 'GCN'
        'num_heads': 4,                # Attention heads for GAT
        'dropout': 0.1,                # Dropout rate

        # Temporal Attention
        'temporal_hidden_dim': 64,     # Temporal attention hidden dim
        'num_temporal_heads': 4,       # Multi-head attention heads
        'temporal_dropout': 0.1,

        # LSTM Decoder
        'lstm_hidden_dim': 64,         # LSTM hidden dimension
        'num_lstm_layers': 2,          # Number of LSTM layers

        # Graph Construction
        'edge_threshold': 0.3,         # Correlation threshold for edges
        'max_neighbors': 8,            # Maximum neighbors per node (k-NN)
        'use_distance_edges': True,    # Include distance-based edges
        'use_elevation_edges': True,   # Include elevation-based edges
        'use_correlation_edges': True, # Include correlation-based edges

        # Graph construction parameters (previously hardcoded)
        'distance_scale_km': 10.0,     # Scale for distance similarity
        'elevation_scale': 0.2,        # Scale for elevation similarity
        'elevation_weight': 0.3,       # Weight for elevation edges
        'correlation_weight': 0.5,     # Weight for correlation edges
        'min_edge_weight': 0.01,       # Minimum edge weight to keep
        'max_edges': 500_000,          # Edge budget. The thresholded graph is far denser than this,
                                       # so this cap is what actually sets the graph size: the model
                                       # sees the max_edges highest-weight edges, not every edge above
                                       # edge_threshold. Report both numbers together.
    }
}

# Auto-set paths (V2/V3 Compatible - same dataset)
# Use local copy in Colab for faster/reliable access
if IN_COLAB and USE_LOCAL_DATA:
    CONFIG['data_file'] = Path(LOCAL_DATA_FILE)
else:
    CONFIG['data_file'] = CONFIG['base_path'] / 'data' / 'output' / (
        'complete_dataset_with_features_with_clusters_elevation_windows_imfs_with_onehot_elevation_clean.nc'
    )
# =============================================================================
# ABLATION MODES
# =============================================================================
# Set ABLATION to None for a production run. Each mode changes exactly one thing
# and writes to its own out_root, so no ablation can overwrite a production run.
#
#   'leaked_graph'  Correlation edges over the full record instead of the
#                   training period. RESULT (2026-08-02, three seeds): mean R2
#                   0.4442 against 0.4462 corrected, a difference of -0.002.
#                   The leakage had no measurable effect on performance. It is
#                   still a defect and stays fixed, but it does not explain the
#                   gap to the archived results.
#
#   'batch2'        batch_size 2, as the archived run used. RESULT: it
#                   reproduces the archived TRAINING curve almost exactly (train
#                   loss 0.5886, 0.3647, 0.3095, 0.2764 against the archived
#                   0.5904, 0.3687, 0.3079, 0.2764) but gives a WORSE R2, mean
#                   0.3476 against 0.4462 at batch_size 4. Ruled out.
#
#   'no_tf32'       Full fp32 matmuls. This is the last systematic difference
#                   left between the current pipeline and the archived run: TF32
#                   was enabled in v4.6 and truncates the matmul mantissa from
#                   24 bits to 10. The model selects its checkpoint at epoch 3
#                   to 6, where it is still far from converged, so reduced
#                   precision plausibly costs more here than in a long run.
#
# Memory is unchanged by 'batch2': peak is set by one chunk of 30 timesteps over
# 500,000 edges, not by the batch. Expect the same 27 GB and roughly the same
# per-epoch time, with more optimizer overhead.

# ABLATION is declared in cell 1, beside the version banner, so the experiment
# being run is visible before the run starts rather than 300 lines into it.
if 'ABLATION' not in globals():
    raise NameError("ABLATION is not defined. Run the version banner cell first.")

_VALID_ABLATIONS = (None, 'leaked_graph', 'batch2', 'no_tf32')
if ABLATION not in _VALID_ABLATIONS:
    raise ValueError(f"ABLATION must be one of {_VALID_ABLATIONS}, got {ABLATION!r}")

# Kept for the graph-construction cell, which reads it to choose the correlation window.
ABLATION_LEAKED_GRAPH = (ABLATION == 'leaked_graph')

_out_dir_name = 'V4_GNN_TAT_Models'

# A run plan may redirect the output tree and change the stopping rule. Both are
# applied here, after the ablation block, so that one place decides where a run
# writes and the banner in cell 1 has already announced it.
if globals().get('PLAN_OUT_SUFFIX'):
    _out_dir_name = f'V4_GNN_TAT_Models_{PLAN_OUT_SUFFIX}'
for _k, _v in (globals().get('PLAN_CONFIG') or {}).items():
    if _k not in CONFIG:
        raise KeyError(f"RUN_PLAN overrides CONFIG[{_k!r}], which does not exist. "
                       f"A typo here would silently do nothing.")
    print(f"[RUN_PLAN] CONFIG[{_k!r}]: {CONFIG[_k]!r} -> {_v!r}")
    CONFIG[_k] = _v
if globals().get('PLAN_CONFIG'):
    print(f"[RUN_PLAN] lr_patience stays {CONFIG['lr_patience']}: the scheduler is "
          f"pinned so a change to early stopping does not move it")

if ABLATION == 'leaked_graph':
    _out_dir_name = 'V4_GNN_TAT_Models_leaked_graph'
elif ABLATION == 'batch2':
    CONFIG['batch_size'] = 2
    _out_dir_name = 'V4_GNN_TAT_Models_batch2'
elif ABLATION == 'no_tf32':
    import torch as _t
    _t.backends.cuda.matmul.allow_tf32 = False
    _t.backends.cudnn.allow_tf32 = False
    _out_dir_name = 'V4_GNN_TAT_Models_no_tf32'

if ABLATION:
    print('=' * 70)
    print(f'ABLATION: {ABLATION}')
    if ABLATION == 'leaked_graph':
        print('  Correlation edges will use every month, including the held-out ones.')
        print('  Diagnostic only. Never report these as model performance.')
    elif ABLATION == 'batch2':
        print(f"  batch_size      : {CONFIG['batch_size']} (production uses 4)")
        print('  Purpose: test whether the archived R2=0.628 is reproducible.')
    else:
        import torch as _t
        print(f"  TF32 matmul     : {_t.backends.cuda.matmul.allow_tf32} (production enables it)")
        print('  Purpose: the last systematic difference from the archived run.')
    print(f"  out_root        : .../{_out_dir_name}")
    print('=' * 70)

CONFIG['out_root'] = CONFIG['base_path'] / 'models' / 'output' / _out_dir_name

# Create output directory
CONFIG['out_root'].mkdir(parents=True, exist_ok=True)

print("Configuration loaded:")
print(f"  Input window: {CONFIG['input_window']} months")
print(f"  Horizon: {CONFIG['horizon']} months")
print(f"  Light mode: {CONFIG['light_mode']} ({CONFIG['light_grid_size']}x{CONFIG['light_grid_size']} grid)")
print(f"  GNN type: {CONFIG['gnn_config']['gnn_type']}")
print(f"  Hidden dim: {CONFIG['gnn_config']['hidden_dim']}")
print(f"  Output directory: {CONFIG['out_root']}")
# Out:
# [RUN_PLAN] CONFIG['patience']: 15 -> 30
# [RUN_PLAN] lr_patience stays 7: the scheduler is pinned so a change to early stopping does not move it
# Configuration loaded:
#   Input window: 60 months
#   Horizon: 12 months
#   Light mode: False (5x5 grid)
#   GNN type: GAT
#   Hidden dim: 64
#   Output directory: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30

# %%
# ==================================================
# MULTI-SEED REPRODUCIBILITY CONFIG
# ==================================================
# Controls whether to run the legacy single seed (42) or iterate
# over multiple seeds for robustness reporting.
#
# When MULTI_SEED=False (default):
#   - Behavior is identical to the pre-modification notebook.
#   - Output paths are unchanged (non-seed-scoped).
#   - NO explicit seed calls are added (the v4 notebook had none originally).
#
# When MULTI_SEED=True:
#   - The training loop iterates over SEEDS.
#   - Each seed gets its own output directory: SEED{seed}/...
#   - Full seed setup (torch/numpy/random/cudnn) is applied per-seed.
#   - SKIP_EXISTING=True avoids re-training seeds that have complete outputs.

MULTI_SEED = True             # default: False (backward compat)
SEEDS = list(PLAN_SEEDS) if _plan else [42, 123, 456]   # set by RUN_PLAN, cell 1
SKIP_EXISTING = PLAN_SKIP_EXISTING if _plan else False  # set by RUN_PLAN; True protects finished runs
LEGACY_SEED = 42               # conventional label for existing non-scoped outputs

# Mutable global: the seed currently being processed. Set inside the
# training loop; read by _seed_out_root() so downstream cells (e.g., map
# exports, consolidation) use the correct seed-scoped paths.
CURRENT_SEED = LEGACY_SEED


def _resolve_seeds():
    """Return the list of seeds to iterate over.

    Falls back to [LEGACY_SEED] when MULTI_SEED is False or SEEDS is empty.
    """
    if not MULTI_SEED:
        return [LEGACY_SEED]
    if not SEEDS:
        print("[WARN] MULTI_SEED=True but SEEDS is empty; using [LEGACY_SEED]")
        return [LEGACY_SEED]
    return list(SEEDS)


def get_seed_scoped_path(seed, base_path):
    """Return a seed-scoped path: base / f'SEED{seed}'.

    When MULTI_SEED=False, returns base_path unchanged (legacy behavior).
    """
    from pathlib import Path
    base = Path(base_path)
    if not MULTI_SEED:
        return base
    return base / f'SEED{seed}'


def _seed_out_root():
    """Shorthand: return the seed-scoped root for the CURRENT_SEED."""
    return get_seed_scoped_path(CURRENT_SEED, CONFIG['out_root'])


def is_seed_output_complete(seed, horizon, exp_name, model_name):
    """Return True iff all expected output files for this (seed, horizon, exp,
    model) tuple exist and are non-empty.

    Expected files (relative to get_seed_scoped_path(seed, CONFIG['out_root'])):
      - map_exports/H{horizon}/{exp_name}/{model_name}/predictions.npy
      - map_exports/H{horizon}/{exp_name}/{model_name}/targets.npy
      - map_exports/H{horizon}/{exp_name}/{model_name}/metadata.json
    """
    from pathlib import Path
    scoped = get_seed_scoped_path(seed, CONFIG['out_root'])
    export_dir = scoped / 'map_exports' / f'H{horizon}' / exp_name / model_name
    for name in ('predictions.npy', 'targets.npy', 'metadata.json'):
        f = export_dir / name
        if not f.exists() or f.stat().st_size == 0:
            return False
    return True


def _apply_seeds_v4(seed):
    """Full seed setup for v4 (PyTorch). Applied ONLY when MULTI_SEED=True."""
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# Summary print
_active = _resolve_seeds()
print(f"[MULTI_SEED] MULTI_SEED={MULTI_SEED}, SEEDS={SEEDS}, LEGACY_SEED={LEGACY_SEED}")
print(f"[MULTI_SEED] Seeds to iterate: {_active}")
print(f"[MULTI_SEED] SKIP_EXISTING={SKIP_EXISTING}")
if MULTI_SEED:
    print(f"[MULTI_SEED] Output paths will be scoped as SEED{{seed}}/...")
else:
    print(f"[MULTI_SEED] Legacy mode - output paths unchanged.")
# Out:
# [MULTI_SEED] MULTI_SEED=True, SEEDS=[456], LEGACY_SEED=42
# [MULTI_SEED] Seeds to iterate: [456]
# [MULTI_SEED] SKIP_EXISTING=True
# [MULTI_SEED] Output paths will be scoped as SEED{seed}/...

# %% [markdown]
# ## 3. Data Loading and Validation

# %%
# =============================================================================
# CELL 4: Data Loading Functions (V2/V3 Compatible) - IMPROVED
# =============================================================================
# Changes:
# - Better feature validation
# - Multiple NetCDF engines for compatibility (h5netcdf fallback)

def load_and_validate_data(config: Dict) -> Tuple[xr.Dataset, int, int, np.ndarray, np.ndarray]:
    """
    Load dataset and validate features, applying light mode if enabled.
    Tries multiple NetCDF engines for compatibility.
    """
    data_file = config['data_file']
    light_mode = config['light_mode']
    light_grid_size = config['light_grid_size']

    print(f"Loading data from: {data_file}")

    if not Path(data_file).exists():
        raise FileNotFoundError(f"Data file not found: {data_file}")

    # Try multiple engines for NetCDF compatibility
    engines = ['h5netcdf', 'netcdf4', 'scipy']
    ds = None

    for engine in engines:
        try:
            print(f"  Trying engine: {engine}...")
            ds = xr.open_dataset(data_file, engine=engine)
            print(f"  Success with engine: {engine}")
            break
        except Exception as e:
            print(f"  Engine {engine} failed: {type(e).__name__}")
            continue

    if ds is None:
        raise RuntimeError(f"Could not open dataset with any engine. File may be corrupted.")

    print(f"  Original shape: time={len(ds.time)}, lat={len(ds.latitude)}, lon={len(ds.longitude)}")

    # Optional light mode: subset to center region
    if light_mode:
        lat_center = len(ds.latitude) // 2
        lon_center = len(ds.longitude) // 2
        lat_start = lat_center - light_grid_size // 2
        lat_end = lat_start + light_grid_size
        lon_start = lon_center - light_grid_size // 2
        lon_end = lon_start + light_grid_size

        ds = ds.isel(
            latitude=slice(lat_start, lat_end),
            longitude=slice(lon_start, lon_end)
        )
        print(f"  Light mode applied: lat={len(ds.latitude)}, lon={len(ds.longitude)}")

    n_lat = len(ds.latitude)
    n_lon = len(ds.longitude)
    lat_coords = ds.latitude.values
    lon_coords = ds.longitude.values

    # Validate features
    available_vars = set(list(ds.data_vars) + list(ds.coords))
    missing_by_exp = {}
    critical_missing = []

    for exp_name, feats in config['feature_sets'].items():
        missing = [f for f in feats if f not in available_vars]
        if missing:
            missing_by_exp[exp_name] = missing
            if 'total_precipitation' in missing:
                critical_missing.append('total_precipitation')

    if missing_by_exp:
        print(f"  WARNING: Missing features by experiment:")
        for exp, feats in missing_by_exp.items():
            print(f"    {exp}: {feats}")

        if critical_missing:
            raise ValueError(f"Critical features missing: {critical_missing}")
        print(f"  Continuing with available features...")
    else:
        print(f"  All features validated successfully")

    return ds, n_lat, n_lon, lat_coords, lon_coords


# Load data
ds, lat, lon, lat_coords, lon_coords = load_and_validate_data(CONFIG)

print(f"\nData loaded:")
print(f"  Grid size: {lat} x {lon} = {lat * lon} nodes")
print(f"  Time steps: {len(ds.time)}")
print(f"  Latitude range: [{lat_coords.min():.4f}, {lat_coords.max():.4f}]")
print(f"  Longitude range: [{lon_coords.min():.4f}, {lon_coords.max():.4f}]")
# Out:
# Loading data from: /content/dataset_local.nc
#   Trying engine: h5netcdf...
#   Success with engine: h5netcdf
#   Original shape: time=518, lat=61, lon=65
#   All features validated successfully
#
# Data loaded:
#   Grid size: 61 x 65 = 3965 nodes
#   Time steps: 518
#   Latitude range: [4.3750, 7.3750]
#   Longitude range: [-74.9250, -71.7250]

# %% [markdown]
# ## 4. Graph Construction for GNN

# %%
# =============================================================================
# CELL 5: Spatial Graph Construction - IMPROVED
# =============================================================================
# Changes: Uses CONFIG parameters instead of hardcoded magic numbers

class SpatialGraphBuilder:
    """
    Builds a spatial graph from precipitation grid data.

    Nodes: Each grid cell (lat, lon) is a node
    Edges: Based on:
        1. Geographic distance (k-NN or threshold)
        2. Elevation similarity
        3. Historical precipitation correlation
    """

    def __init__(self, lat_coords: np.ndarray, lon_coords: np.ndarray,
                 elevation: np.ndarray, config: Dict):
        """
        Initialize graph builder.

        Args:
            lat_coords: Latitude coordinates (1D array)
            lon_coords: Longitude coordinates (1D array)
            elevation: Elevation values (2D array: lat x lon)
            config: GNN configuration dictionary
        """
        self.lat_coords = lat_coords
        self.lon_coords = lon_coords
        self.elevation = elevation
        self.config = config['gnn_config']

        self.n_lat = len(lat_coords)
        self.n_lon = len(lon_coords)
        self.n_nodes = self.n_lat * self.n_lon

        # Create node positions (lat, lon for each grid cell)
        self.node_positions = self._create_node_positions()

        # Flatten elevation for node features
        self.node_elevations = elevation.flatten()

        print(f"SpatialGraphBuilder initialized:")
        print(f"  Nodes: {self.n_nodes} ({self.n_lat} x {self.n_lon})")

    def _create_node_positions(self) -> np.ndarray:
        """Create (lat, lon) positions for each node."""
        positions = []
        for i, lat in enumerate(self.lat_coords):
            for j, lon in enumerate(self.lon_coords):
                positions.append([lat, lon])
        return np.array(positions)

    def _node_index(self, i: int, j: int) -> int:
        """Convert (lat_idx, lon_idx) to flat node index."""
        return i * self.n_lon + j

    def _flat_to_grid(self, idx: int) -> Tuple[int, int]:
        """Convert flat node index to (lat_idx, lon_idx)."""
        return idx // self.n_lon, idx % self.n_lon

    def compute_distance_matrix(self) -> np.ndarray:
        """
        Compute pairwise distance matrix between all nodes.
        Uses Haversine formula for geographic coordinates.
        """
        # Convert to radians
        pos_rad = np.radians(self.node_positions)

        # Haversine distance
        lat1 = pos_rad[:, 0:1]
        lon1 = pos_rad[:, 1:2]
        lat2 = pos_rad[:, 0:1].T
        lon2 = pos_rad[:, 1:2].T

        dlat = lat2 - lat1
        dlon = lon2 - lon1

        a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
        c = 2 * np.arcsin(np.sqrt(a))

        # Earth radius in km
        R = 6371.0
        distance_km = R * c

        return distance_km

    def compute_elevation_similarity(self) -> np.ndarray:
        """
        Compute elevation similarity matrix.
        Similarity = exp(-|elev_i - elev_j| / scale)
        """
        elev = self.node_elevations.reshape(-1, 1)
        elev_diff = np.abs(elev - elev.T)

        # Normalize by elevation range with configurable scale
        elev_range = elev.max() - elev.min() + 1e-6
        elevation_scale = self.config.get('elevation_scale', 0.2)
        similarity = np.exp(-elev_diff / (elev_range * elevation_scale))

        return similarity

    def compute_correlation_matrix(self, precip_series: np.ndarray) -> np.ndarray:
        """
        Compute precipitation correlation matrix.

        Args:
            precip_series: Precipitation time series (T, lat, lon)

        Returns:
            Correlation matrix (n_nodes, n_nodes)
        """
        T = precip_series.shape[0]

        # Flatten to (T, n_nodes)
        precip_flat = precip_series.reshape(T, -1)

        # Handle NaN values
        precip_flat = np.nan_to_num(precip_flat, nan=0.0)

        # Center the data
        precip_centered = precip_flat - precip_flat.mean(axis=0, keepdims=True)

        # Compute correlation
        std = precip_flat.std(axis=0, keepdims=True) + 1e-8
        precip_norm = precip_centered / std

        correlation = (precip_norm.T @ precip_norm) / T

        # Ensure values in [-1, 1]
        correlation = np.clip(correlation, -1, 1)

        return correlation

    def build_adjacency_matrix(self, precip_series: np.ndarray = None) -> Tuple[np.ndarray, np.ndarray]:
        """
        Build the weighted adjacency matrix combining all edge types.

        Args:
            precip_series: Optional precipitation series for correlation edges

        Returns:
            edge_index: (2, num_edges) tensor of edge indices
            edge_weight: (num_edges,) tensor of edge weights
        """
        max_neighbors = self.config['max_neighbors']
        edge_threshold = self.config['edge_threshold']

        # Get configurable parameters (with defaults for backward compatibility)
        distance_scale = self.config.get('distance_scale_km', 10.0)
        elevation_weight = self.config.get('elevation_weight', 0.3)
        correlation_weight = self.config.get('correlation_weight', 0.5)
        min_edge_weight = self.config.get('min_edge_weight', 0.01)

        # Initialize adjacency with zeros
        adj = np.zeros((self.n_nodes, self.n_nodes))

        # 1. Distance-based edges (k-NN)
        if self.config['use_distance_edges']:
            dist_matrix = self.compute_distance_matrix()

            # Convert distance to similarity (inverse distance)
            dist_matrix[dist_matrix == 0] = 1e-6  # Avoid division by zero
            dist_similarity = 1.0 / (1.0 + dist_matrix / distance_scale)

            # Keep only k nearest neighbors
            for i in range(self.n_nodes):
                # Find k nearest neighbors (excluding self)
                neighbors = np.argsort(dist_matrix[i])[:max_neighbors + 1]
                neighbors = neighbors[neighbors != i][:max_neighbors]
                adj[i, neighbors] += dist_similarity[i, neighbors]

            print(f"  Distance edges added (k={max_neighbors}, scale={distance_scale}km)")

        # 2. Elevation-based edges
        if self.config['use_elevation_edges']:
            elev_sim = self.compute_elevation_similarity()

            # Add elevation similarity to existing edges
            adj += elev_sim * elevation_weight
            print(f"  Elevation edges added (weight={elevation_weight})")

        # 3. Correlation-based edges
        if self.config['use_correlation_edges'] and precip_series is not None:
            corr_matrix = self.compute_correlation_matrix(precip_series)

            # Only keep strong positive correlations
            corr_edges = np.maximum(corr_matrix - edge_threshold, 0)
            adj += corr_edges * correlation_weight
            print(f"  Correlation edges added (threshold={edge_threshold}, weight={correlation_weight})")

        # Remove self-loops (GCN will add them back if needed via add_self_loops=True)
        np.fill_diagonal(adj, 0)

        # Normalize
        adj_max = adj.max()
        if adj_max > 0:
            adj = adj / adj_max

        # Symmetrize
        adj = (adj + adj.T) / 2

        # Convert to sparse format (edge_index, edge_weight).
        # np.nonzero returns row-major order, so this is element for element the
        # same result as the nested loop it replaces, without 15.7M Python
        # iterations on a 3965-node grid.
        rows, cols = np.nonzero(adj > min_edge_weight)
        edge_index = np.vstack((rows, cols))   # Shape: (2, num_edges)
        edge_weight = adj[rows, cols]          # Shape: (num_edges,)

        print(f"  Total edges above min_edge_weight: {len(edge_weight):,}")
        print(f"  Average degree: {len(edge_weight) / self.n_nodes:.2f}")

        # Edge budget. Applied unconditionally so that the graph the model sees is
        # a declared hyperparameter rather than a side effect of whether the
        # thresholded count happened to cross a trigger.
        max_edges = self.config.get('max_edges')
        if max_edges is not None and len(edge_weight) > max_edges:
            keep = np.argsort(edge_weight)[-max_edges:]
            keep.sort()                        # preserve row-major edge ordering
            edge_index = edge_index[:, keep]
            edge_weight = edge_weight[keep]
            print(f"  Edge budget applied: kept the {max_edges:,} highest-weight edges "
                  f"({len(edge_weight) / self.n_nodes:.1f} per node)")

        return edge_index, edge_weight

    def get_node_features(self) -> np.ndarray:
        """
        Get static node features (position, elevation).

        Returns:
            Node features (n_nodes, n_features)
        """
        features = np.column_stack([
            self.node_positions,  # (lat, lon)
            self.node_elevations.reshape(-1, 1)  # elevation
        ])

        # Normalize
        features = (features - features.mean(axis=0)) / (features.std(axis=0) + 1e-8)

        return features.astype(np.float32)


# Build spatial graph
print("\nBuilding spatial graph...")

# Get elevation data
if 'elevation' in ds.data_vars:
    elevation = ds['elevation'].values
    if len(elevation.shape) == 3:  # (time, lat, lon)
        elevation = elevation[0]  # Take first timestep (static)
        print("  Note: Elevation has time dimension, using first timestep")
elif 'elevation' in ds.coords:
    elevation = ds.coords['elevation'].values
else:
    print("WARNING: Elevation not found, using zeros")
    elevation = np.zeros((lat, lon))

# Get precipitation data for correlation
precip_var = 'total_precipitation' if 'total_precipitation' in ds.data_vars else list(ds.data_vars)[0]
precip_series = ds[precip_var].values

# Build graph
graph_builder = SpatialGraphBuilder(lat_coords, lon_coords, elevation, CONFIG)
# Correlation edges must be estimated on the TRAINING period only, otherwise the
# graph's fixed spatial prior encodes information from the held-out months.
# ABLATION_LEAKED_GRAPH deliberately restores the leaked behaviour so the two can
# be compared under an otherwise identical pipeline.
split_idx = int(len(precip_series) * CONFIG.get('train_val_split', 0.8))
if globals().get('ABLATION_LEAKED_GRAPH', False):
    print("  [ABLATION] correlation over the FULL record: this graph leaks the held-out months")
    _corr_series = precip_series
else:
    _corr_series = precip_series[:split_idx]
edge_index, edge_weight = graph_builder.build_adjacency_matrix(_corr_series)
static_node_features = graph_builder.get_node_features()

print(f"\nGraph built:")
print(f"  Nodes: {graph_builder.n_nodes}")
print(f"  Edges: {len(edge_weight)}")
print(f"  Node features shape: {static_node_features.shape}")

# Convert to PyTorch tensors for GNN
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index_tensor = torch.tensor(edge_index, dtype=torch.long).to(device)
edge_weight_tensor = torch.tensor(edge_weight, dtype=torch.float32).to(device)

print(f"Graph tensors created on {device}:")
print(f"  edge_index_tensor: {edge_index_tensor.shape}")
print(f"  edge_weight_tensor: {edge_weight_tensor.shape}")

# Memory check for large grids
n_edges = len(edge_weight)
n_nodes = graph_builder.n_nodes
estimated_memory_gb = (n_nodes * n_edges * 4) / 1e9  # rough estimate

# The edge budget is now applied inside build_adjacency_matrix, so it is part of
# the graph definition and is reported with it. This block only reports the result.
#
# The guard it replaces fired only above 1,000,000 edges, which made the graph a
# discontinuous function of the data: the leakage fix moved the thresholded count
# across that trigger and would have halved the graph without the change being
# visible in any hyperparameter.
print(f"  Graph in use: {n_edges:,} edges over {n_nodes:,} nodes "
      f"({n_edges / n_nodes:.1f} per node)")
print(f"  Estimated dense-adjacency equivalent: {estimated_memory_gb:.1f} GB")
# Out:
# Building spatial graph...
#   Note: Elevation has time dimension, using first timestep
# SpatialGraphBuilder initialized:
#   Nodes: 3965 (61 x 65)
#   Distance edges added (k=8, scale=10.0km)
#   Elevation edges added (weight=0.3)
#   Correlation edges added (threshold=0.3, weight=0.5)
#   Total edges above min_edge_weight: 15,673,588
#   Average degree: 3952.99
#   Edge budget applied: kept the 500,000 highest-weight edges (126.1 per node)
#
# Graph built:
#   Nodes: 3965
#   Edges: 500000
#   Node features shape: (3965, 3)
# Graph tensors created on cuda:
#   edge_index_tensor: torch.Size([2, 500000])
#   edge_weight_tensor: torch.Size([500000])
#   Graph in use: 500,000 edges over 3,965 nodes (126.1 per node)
#   Estimated dense-adjacency equivalent: 7.9 GB

# %%
# =============================================================================
# CELL 6: Visualize Graph Structure
# =============================================================================

def visualize_graph(graph_builder: SpatialGraphBuilder, edge_index: np.ndarray,
                   edge_weight: np.ndarray, title: str = "Spatial Graph"):
    """
    Visualize the spatial graph structure.
    """
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    # 1. Node positions with edges
    ax1 = axes[0]
    pos = graph_builder.node_positions

    # Draw edges (sample if too many)
    n_edges_to_draw = min(500, len(edge_weight))
    edge_indices = np.random.choice(len(edge_weight), n_edges_to_draw, replace=False)

    for idx in edge_indices:
        i, j = edge_index[0, idx], edge_index[1, idx]
        ax1.plot([pos[i, 1], pos[j, 1]], [pos[i, 0], pos[j, 0]],
                'b-', alpha=0.2, linewidth=0.5)

    # Draw nodes
    scatter = ax1.scatter(pos[:, 1], pos[:, 0], c=graph_builder.node_elevations,
                         cmap='terrain', s=100, edgecolors='black', linewidth=0.5)
    plt.colorbar(scatter, ax=ax1, label='Elevation (m)')
    ax1.set_xlabel('Longitude')
    ax1.set_ylabel('Latitude')
    ax1.set_title('Graph Structure (colored by elevation)')

    # 2. Edge weight distribution
    ax2 = axes[1]
    ax2.hist(edge_weight, bins=50, color='steelblue', edgecolor='black')
    ax2.set_xlabel('Edge Weight')
    ax2.set_ylabel('Frequency')
    ax2.set_title('Edge Weight Distribution')
    ax2.axvline(np.mean(edge_weight), color='red', linestyle='--', label=f'Mean: {np.mean(edge_weight):.3f}')
    ax2.legend()

    # 3. Node degree distribution
    ax3 = axes[2]
    degrees = np.bincount(edge_index[0], minlength=graph_builder.n_nodes)
    ax3.hist(degrees, bins=20, color='forestgreen', edgecolor='black')
    ax3.set_xlabel('Node Degree')
    ax3.set_ylabel('Frequency')
    ax3.set_title('Node Degree Distribution')
    ax3.axvline(np.mean(degrees), color='red', linestyle='--', label=f'Mean: {np.mean(degrees):.1f}')
    ax3.legend()

    plt.suptitle(title, fontsize=14, fontweight='bold')
    plt.tight_layout()

    # Save figure
    fig_path = CONFIG['out_root'] / 'graph_visualization.png'
    plt.savefig(fig_path, dpi=150, bbox_inches='tight')
    print(f"Graph visualization saved to: {fig_path}")

    plt.show()


# Visualize
visualize_graph(graph_builder, edge_index, edge_weight,
               title=f"GNN-TAT Spatial Graph ({lat}x{lon} grid)")
# Out:
# Graph visualization saved to: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/graph_visualization.png

# %% [markdown]
# ## 5. Data Preprocessing Pipeline

# %%
# =============================================================================
# CELL 7: Data Preprocessing (V2/V3 Compatible)
# =============================================================================

def windowed_arrays(X: np.ndarray, y: np.ndarray, input_window: int,
                   horizon: int, start_indices: List[int] = None) -> Tuple[np.ndarray, np.ndarray]:
    """
    Create windowed arrays for sequence-to-sequence learning.

    Args:
        X: Input features (T, lat, lon, n_features)
        y: Target variable (T, lat, lon)
        input_window: Number of input timesteps
        horizon: Number of output timesteps
        start_indices: Optional list of valid start indices

    Returns:
        seq_X: (N, input_window, lat, lon, n_features)
        seq_y: (N, horizon, lat, lon)
    """
    seq_X, seq_y = [], []
    T = len(X)

    if T < (input_window + horizon):
        raise ValueError(f"Not enough timesteps ({T}) for windows")

    if start_indices is None:
        start_indices = range(T - input_window - horizon + 1)

    for start in start_indices:
        end_w = start + input_window
        end_y = end_w + horizon

        if end_y > T:
            continue

        Xw = X[start:end_w]
        yw = y[end_w:end_y]

        # Skip windows with NaNs
        if np.isnan(Xw).any() or np.isnan(yw).any():
            continue

        seq_X.append(Xw)
        seq_y.append(yw)

    if len(seq_X) == 0:
        raise ValueError("No valid windows created")

    return np.asarray(seq_X, dtype=np.float32), np.asarray(seq_y, dtype=np.float32)


def compute_split_indices(total_steps: int, input_window: int, horizon: int,
                         split_ratio: float) -> Tuple[List[int], List[int]]:
    """
    Return train/validation start indices ensuring no temporal leakage.

    Args:
        total_steps: Total number of timesteps
        input_window: Input window size
        horizon: Prediction horizon
        split_ratio: Train ratio (e.g., 0.8)

    Returns:
        train_indices: List of training window start indices
        val_indices: List of validation window start indices
    """
    cutoff = int(total_steps * split_ratio)
    max_start = total_steps - input_window - horizon + 1

    # Training indices: before cutoff
    train_end = max(0, cutoff - input_window - horizon + 1)
    train_indices = list(range(0, train_end))

    # Validation indices: from cutoff onward
    val_start = min(max_start, max(cutoff, 0))
    val_indices = list(range(val_start, max_start))

    if not train_indices:
        raise ValueError("Empty training set")
    if not val_indices:
        raise ValueError("Empty validation set")

    return train_indices, val_indices


def preprocess_data(ds: xr.Dataset, config: Dict, n_lat: int, n_lon: int,
                   horizon: int) -> Dict[str, Tuple]:
    """
    Preprocess data for all feature sets.

    Returns:
        Dictionary mapping experiment name to (X_tr, y_tr, X_va, y_va, scaler)
    """
    input_window = config['input_window']
    split_ratio = config['train_val_split']

    results = {}

    for exp_name, feature_list in config['feature_sets'].items():
        print(f"\nProcessing experiment: {exp_name}")

        try:
            # Extract features
            feature_arrays = []
            for feat in feature_list:
                if feat in ds.data_vars:
                    arr = ds[feat].values
                elif feat in ds.coords:
                    # Broadcast coordinate to full grid
                    if feat == 'time':
                        continue
                    arr = np.broadcast_to(
                        ds.coords[feat].values.reshape(-1, 1, 1),
                        (len(ds.time), n_lat, n_lon)
                    )
                else:
                    print(f"  WARNING: Feature '{feat}' not found, skipping")
                    continue

                # Ensure 3D shape (T, lat, lon)
                if len(arr.shape) == 2:
                    # Static feature: broadcast to time
                    arr = np.broadcast_to(arr, (len(ds.time), n_lat, n_lon))

                feature_arrays.append(arr)

            # Stack features: (T, lat, lon, n_features)
            X = np.stack(feature_arrays, axis=-1).astype(np.float32)

            # Target: total precipitation
            y = ds['total_precipitation'].values.astype(np.float32)

            print(f"  X shape: {X.shape}")
            print(f"  y shape: {y.shape}")

            # Handle NaN
            X = np.nan_to_num(X, nan=0.0)
            y = np.nan_to_num(y, nan=0.0)

            # Compute split indices
            T = len(ds.time)
            train_idx, val_idx = compute_split_indices(T, input_window, horizon, split_ratio)

            print(f"  Train windows: {len(train_idx)}, Val windows: {len(val_idx)}")

            # Create windows
            X_tr, y_tr = windowed_arrays(X, y, input_window, horizon, train_idx)
            X_va, y_va = windowed_arrays(X, y, input_window, horizon, val_idx)

            # Scale features
            scaler_X = StandardScaler()
            scaler_y = StandardScaler()

            # Fit on training data only
            X_tr_flat = X_tr.reshape(-1, X_tr.shape[-1])
            y_tr_flat = y_tr.reshape(-1, 1)

            scaler_X.fit(X_tr_flat)
            scaler_y.fit(y_tr_flat)

            # Transform
            X_tr_shape = X_tr.shape
            X_va_shape = X_va.shape
            y_tr_shape = y_tr.shape
            y_va_shape = y_va.shape

            X_tr_sc = scaler_X.transform(X_tr.reshape(-1, X_tr.shape[-1])).reshape(X_tr_shape)
            X_va_sc = scaler_X.transform(X_va.reshape(-1, X_va.shape[-1])).reshape(X_va_shape)
            y_tr_sc = scaler_y.transform(y_tr.reshape(-1, 1)).reshape(y_tr_shape)
            y_va_sc = scaler_y.transform(y_va.reshape(-1, 1)).reshape(y_va_shape)

            # Add channel dimension to y: (N, H, lat, lon) -> (N, H, lat, lon, 1)
            y_tr_sc = np.expand_dims(y_tr_sc, -1)
            y_va_sc = np.expand_dims(y_va_sc, -1)

            print(f"  Final shapes: X_tr={X_tr_sc.shape}, y_tr={y_tr_sc.shape}")
            print(f"                X_va={X_va_sc.shape}, y_va={y_va_sc.shape}")

            results[exp_name] = (X_tr_sc, y_tr_sc, X_va_sc, y_va_sc, scaler_y)

        except Exception as e:
            print(f"  ERROR: {e}")
            continue

    return results


# Preprocess data for default horizon
print("Preprocessing data...")
data_splits = preprocess_data(ds, CONFIG, lat, lon, CONFIG['horizon'])

print(f"\nPreprocessing complete. Available experiments: {list(data_splits.keys())}")
# Out:
# Preprocessing data...
#
# Processing experiment: BASIC
#   X shape: (518, 61, 65, 12)
#   y shape: (518, 61, 65)
#   Train windows: 343, Val windows: 33
#   Final shapes: X_tr=(343, 60, 61, 65, 12), y_tr=(343, 12, 61, 65, 1)
#                 X_va=(33, 60, 61, 65, 12), y_va=(33, 12, 61, 65, 1)
#
# Processing experiment: KCE
#   X shape: (518, 61, 65, 15)
#   y shape: (518, 61, 65)
#   Train windows: 343, Val windows: 33
#   Final shapes: X_tr=(343, 60, 61, 65, 15), y_tr=(343, 12, 61, 65, 1)
#                 X_va=(33, 60, 61, 65, 15), y_va=(33, 12, 61, 65, 1)
#
# Processing experiment: PAFC
#   X shape: (518, 61, 65, 18)
#   y shape: (518, 61, 65)
#   Train windows: 343, Val windows: 33
#   Final shapes: X_tr=(343, 60, 61, 65, 18), y_tr=(343, 12, 61, 65, 1)
#                 X_va=(33, 60, 61, 65, 18), y_va=(33, 12, 61, 65, 1)
#
# Preprocessing complete. Available experiments: ['BASIC', 'KCE', 'PAFC']

# %% [markdown]
# ## 6. GNN-TAT Model Architecture

# %%
# =============================================================================
# CELL 8: GNN-TAT Model Definition (PyTorch) - MEMORY OPTIMIZED
# =============================================================================
# Fixes applied:
# - Proper residual connection in TemporalAttention
# - CHUNKED GNN processing to avoid OOM on large grids
# - Reduced model dimensions (~100K params)
# - GCN with add_self_loops=True for stability
# - Memory cleanup between chunks

class TemporalAttention(nn.Module):
    """
    Multi-Head Temporal Attention module with proper residual connection.
    """

    def __init__(self, input_dim: int, hidden_dim: int, num_heads: int, dropout: float = 0.1):
        super().__init__()

        self.num_heads = num_heads
        self.head_dim = hidden_dim // num_heads
        self.hidden_dim = hidden_dim
        self.input_dim = input_dim

        assert hidden_dim % num_heads == 0, "hidden_dim must be divisible by num_heads"

        # Query, Key, Value projections
        self.q_proj = nn.Linear(input_dim, hidden_dim)
        self.k_proj = nn.Linear(input_dim, hidden_dim)
        self.v_proj = nn.Linear(input_dim, hidden_dim)

        # Output projection
        self.out_proj = nn.Linear(hidden_dim, hidden_dim)

        # Residual projection (if dimensions differ)
        self.residual_proj = nn.Linear(input_dim, hidden_dim) if input_dim != hidden_dim else nn.Identity()

        # Layer norm and dropout
        self.layer_norm = nn.LayerNorm(hidden_dim)
        self.dropout = nn.Dropout(dropout)

        # Scaling factor
        self.scale = self.head_dim ** -0.5

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        batch_size, seq_len, _ = x.shape

        # Save input for residual (with projection if needed)
        residual = self.residual_proj(x)

        # Project to Q, K, V
        Q = self.q_proj(x)
        K = self.k_proj(x)
        V = self.v_proj(x)

        # Reshape for multi-head attention
        Q = Q.view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)
        K = K.view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)
        V = V.view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)

        # Attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) * self.scale
        attn_probs = F.softmax(attn_scores, dim=-1)
        attn_probs = self.dropout(attn_probs)

        # Apply attention to values
        attn_output = torch.matmul(attn_probs, V)

        # Reshape and project output
        attn_output = attn_output.transpose(1, 2).contiguous().view(batch_size, seq_len, self.hidden_dim)
        output = self.out_proj(attn_output)

        # Proper residual connection: residual + dropout(output)
        output = self.layer_norm(residual + self.dropout(output))

        return output


class SpatialGNNEncoder(nn.Module):
    """
    GNN Encoder for spatial dependencies.
    Supports GCN, GAT, and GraphSAGE with proper handling.
    """

    def __init__(self, input_dim: int, hidden_dim: int, num_layers: int,
                 gnn_type: str = 'GAT', num_heads: int = 4, dropout: float = 0.1):
        super().__init__()

        self.num_layers = num_layers
        self.gnn_type = gnn_type
        self.hidden_dim = hidden_dim

        # Input projection
        self.input_proj = nn.Linear(input_dim, hidden_dim)

        # GNN layers
        self.gnn_layers = nn.ModuleList()
        self.norms = nn.ModuleList()

        for i in range(num_layers):
            if gnn_type == 'GAT':
                layer = GATConv(
                    in_channels=hidden_dim,
                    out_channels=hidden_dim // num_heads,
                    heads=num_heads,
                    dropout=dropout,
                    concat=True
                )
            elif gnn_type == 'SAGE':
                layer = SAGEConv(
                    in_channels=hidden_dim,
                    out_channels=hidden_dim,
                    aggr='mean'
                )
            else:  # GCN
                layer = GCNConv(
                    in_channels=hidden_dim,
                    out_channels=hidden_dim,
                    add_self_loops=True,
                    normalize=True
                )

            self.gnn_layers.append(layer)
            self.norms.append(nn.LayerNorm(hidden_dim))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor, edge_index: torch.Tensor,
                edge_weight: torch.Tensor = None) -> torch.Tensor:
        # Input projection
        x = self.input_proj(x)

        # GNN layers with residual connections
        for gnn, norm in zip(self.gnn_layers, self.norms):
            residual = x

            if self.gnn_type == 'GAT':
                x = gnn(x, edge_index)
            elif self.gnn_type == 'SAGE':
                x = gnn(x, edge_index)
            else:  # GCN
                x = gnn(x, edge_index, edge_weight)

            x = F.gelu(x)
            x = self.dropout(x)
            x = norm(x + residual)

        return x


class GNN_TAT(nn.Module):
    """
    Graph Neural Network with Temporal Attention - MEMORY OPTIMIZED.

    Key optimizations for full grid support:
    - CHUNKED GNN processing (processes timesteps in chunks)
    - Memory cleanup between chunks
    - Efficient temporal processing
    """

    def __init__(self, n_features: int, n_nodes: int, n_lat: int, n_lon: int,
                 horizon: int, config: Dict, gnn_chunk_size: int = 15):
        super().__init__()

        self.n_features = n_features
        self.n_nodes = n_nodes
        self.n_lat = n_lat
        self.n_lon = n_lon
        self.horizon = horizon
        self.gnn_chunk_size = gnn_chunk_size  # Process this many timesteps at once
        self.use_grad_checkpoint = config.get('gnn_grad_checkpoint', True)

        gnn_cfg = config['gnn_config']
        # Only GCNConv reads edge_weight. Building and repeating it for GAT/SAGE
        # allocates a tensor of |E| * chunk floats that is then discarded.
        self._needs_edge_weight = (gnn_cfg['gnn_type'] == 'GCN')
        # The batched edge_index for a given chunk size is a constant of the run,
        # but was being rebuilt for every chunk and again on every checkpoint
        # recompute: ~8 rebuilds of a 2 x (chunk * |E|) int64 tensor per step.
        self._edge_cache = {}
        hidden_dim = gnn_cfg['hidden_dim']
        self.hidden_dim = hidden_dim

        # GNN Encoder
        self.gnn_encoder = SpatialGNNEncoder(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            num_layers=gnn_cfg['num_gnn_layers'],
            gnn_type=gnn_cfg['gnn_type'],
            num_heads=gnn_cfg['num_heads'],
            dropout=gnn_cfg['dropout']
        )

        # Temporal Attention (per node, efficient)
        self.temporal_attention = TemporalAttention(
            input_dim=hidden_dim,
            hidden_dim=hidden_dim,
            num_heads=gnn_cfg['num_temporal_heads'],
            dropout=gnn_cfg['temporal_dropout']
        )

        # LSTM for sequence modeling (per node)
        self.lstm = nn.LSTM(
            input_size=hidden_dim,
            hidden_size=hidden_dim,
            num_layers=gnn_cfg['num_lstm_layers'],
            batch_first=True,
            dropout=gnn_cfg['dropout'] if gnn_cfg['num_lstm_layers'] > 1 else 0
        )

        # Output projection (per node -> horizon predictions)
        self.output_proj = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(gnn_cfg['dropout']),
            nn.Linear(hidden_dim, horizon)
        )

        self._print_model_info(gnn_cfg)

    def _print_model_info(self, gnn_cfg):
        total_params = sum(p.numel() for p in self.parameters())
        print(f"GNN-TAT Model initialized (MEMORY OPTIMIZED):")
        print(f"  Input: ({self.n_features} features, {self.n_nodes} nodes)")
        print(f"  Output: (horizon={self.horizon}, {self.n_lat}x{self.n_lon} grid)")
        print(f"  GNN type: {gnn_cfg['gnn_type']}")
        print(f"  Hidden dim: {gnn_cfg['hidden_dim']}")
        print(f"  GNN chunk size: {self.gnn_chunk_size} timesteps")
        print(f"  Parameters: {total_params:,}")

    def _batched_edges(self, edge_index: torch.Tensor, edge_weight: torch.Tensor,
                       num_graphs: int, device: torch.device):
        """Batched edge_index (and weight) for num_graphs replicas, cached.

        A full training run uses at most two distinct chunk sizes (the nominal one
        and the remainder), so the cache holds at most two entries.
        """
        key = (num_graphs, device)
        hit = self._edge_cache.get(key)
        if hit is not None:
            return hit
        bidx = self._batch_edge_index(edge_index, num_graphs, device)
        bw = None
        if self._needs_edge_weight and edge_weight is not None:
            bw = edge_weight.repeat(num_graphs)
        self._edge_cache[key] = (bidx, bw)
        return bidx, bw

    def clear_edge_cache(self):
        self._edge_cache.clear()

    def _process_gnn_chunk(self, x_chunk: torch.Tensor, edge_index: torch.Tensor,
                           edge_weight: torch.Tensor = None) -> torch.Tensor:
        """Process a chunk of timesteps through GNN."""
        chunk_size = x_chunk.shape[0]  # num_graphs in this chunk
        device = x_chunk.device

        batch_edge_index, batch_edge_weight = self._batched_edges(
            edge_index, edge_weight, chunk_size, device)

        # Flatten nodes: (chunk_size * n_nodes, n_features)
        x_nodes = x_chunk.view(-1, self.n_features)

        # Apply GNN
        gnn_out = self.gnn_encoder(x_nodes, batch_edge_index, batch_edge_weight)

        # Reshape: (chunk_size, n_nodes, hidden_dim)
        gnn_out = gnn_out.view(chunk_size, self.n_nodes, self.hidden_dim)

        return gnn_out

    def forward(self, x: torch.Tensor, edge_index: torch.Tensor,
                edge_weight: torch.Tensor = None) -> torch.Tensor:
        batch_size, seq_len = x.shape[:2]
        device = x.device

        # Reshape: (batch, seq_len, lat, lon, features) -> (batch, seq_len, n_nodes, features)
        x = x.view(batch_size, seq_len, self.n_nodes, self.n_features)

        # Flatten batch and seq_len: (batch * seq_len, n_nodes, features)
        x_flat = x.view(batch_size * seq_len, self.n_nodes, self.n_features)
        total_graphs = batch_size * seq_len

        # CHUNKED GNN Processing to avoid OOM
        gnn_outputs = []
        for start_idx in range(0, total_graphs, self.gnn_chunk_size):
            end_idx = min(start_idx + self.gnn_chunk_size, total_graphs)
            chunk = x_flat[start_idx:end_idx]  # (chunk_size, n_nodes, features)

            # Process chunk
            # Gradient checkpointing: discard chunk activations and recompute them in
            # backward. Without this, every chunk's autograd graph is retained until
            # backward, so peak memory grows with the number of chunks and chunking
            # buys nothing during training. Math is unchanged.
            if self.training and getattr(self, 'use_grad_checkpoint', True):
                chunk_out = torch.utils.checkpoint.checkpoint(
                    self._process_gnn_chunk, chunk, edge_index, edge_weight,
                    use_reentrant=False)
            else:
                chunk_out = self._process_gnn_chunk(chunk, edge_index, edge_weight)
            gnn_outputs.append(chunk_out)

        # Concatenate all chunks
        gnn_out = torch.cat(gnn_outputs, dim=0)  # (batch * seq_len, n_nodes, hidden)
        del gnn_outputs

        # Reshape back: (batch, seq_len, n_nodes, hidden_dim)
        gnn_out = gnn_out.view(batch_size, seq_len, self.n_nodes, self.hidden_dim)

        # Temporal Processing (per node)
        temporal_in = gnn_out.permute(0, 2, 1, 3)  # (batch, n_nodes, seq_len, hidden)
        temporal_in = temporal_in.reshape(batch_size * self.n_nodes, seq_len, self.hidden_dim)

        # Apply temporal attention
        temporal_out = self.temporal_attention(temporal_in)

        # Apply LSTM
        lstm_out, _ = self.lstm(temporal_out)

        # Take last timestep: (batch * n_nodes, hidden)
        lstm_last = lstm_out[:, -1, :]

        # Output Projection
        out = self.output_proj(lstm_last)  # (batch * n_nodes, horizon)

        # Reshape: (batch, n_nodes, horizon) -> (batch, horizon, lat, lon, 1)
        out = out.view(batch_size, self.n_nodes, self.horizon)
        out = out.permute(0, 2, 1)  # (batch, horizon, n_nodes)
        out = out.view(batch_size, self.horizon, self.n_lat, self.n_lon, 1)

        return out

    def _batch_edge_index(self, edge_index: torch.Tensor, num_graphs: int,
                          device: torch.device) -> torch.Tensor:
        """Create batched edge_index by replicating and offsetting indices."""
        num_edges = edge_index.shape[1]

        # Create offsets for each graph
        offsets = torch.arange(num_graphs, device=device) * self.n_nodes
        offsets = offsets.view(-1, 1, 1).expand(-1, 2, num_edges)

        # Replicate edge_index and add offsets
        batch_edge_index = edge_index.unsqueeze(0).expand(num_graphs, -1, -1)
        batch_edge_index = batch_edge_index + offsets

        # Flatten: (num_graphs, 2, num_edges) -> (2, num_graphs * num_edges)
        batch_edge_index = batch_edge_index.permute(1, 0, 2).reshape(2, -1)

        return batch_edge_index


# Chunk size comes from CONFIG, as it does at the two construction sites that
# train. A heuristic used to set it here from the grid size, which meant this
# probe announced a value the trained models did not use: 2 on the full grid
# while training ran at 30, and 60 on a light grid. The banner tells the reader
# to abort on seeing chunk size 2 or 15, so an announcement that does not match
# the run is worse than none.
n_nodes_estimate = lat * lon if 'lat' in dir() and 'lon' in dir() else 425
GNN_CHUNK_SIZE = CONFIG['gnn_chunk_size']

print(f"\nEstimated grid size: {n_nodes_estimate} nodes")
print(f"Using GNN chunk size: {GNN_CHUNK_SIZE} timesteps per chunk (from CONFIG)")

# Create model
print("\nCreating GNN-TAT model...")

# Get number of features from first experiment
first_exp = list(data_splits.keys())[0]
n_features = data_splits[first_exp][0].shape[-1]

# Initialize model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = GNN_TAT(
    n_features=n_features,
    n_nodes=graph_builder.n_nodes,
    n_lat=lat,
    n_lon=lon,
    horizon=CONFIG['horizon'],
    config=CONFIG,
    gnn_chunk_size=GNN_CHUNK_SIZE
)
model = model.to(device)

# Print memory estimate
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"\nGPU Memory after model init: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
# Out:
# Estimated grid size: 3965 nodes
# Using GNN chunk size: 30 timesteps per chunk (from CONFIG)
#
# Creating GNN-TAT model...
# Using device: cuda
# GNN-TAT Model initialized (MEMORY OPTIMIZED):
#   Input: (12 features, 3965 nodes)
#   Output: (horizon=12, 61x65 grid)
#   GNN type: GAT
#   Hidden dim: 64
#   GNN chunk size: 30 timesteps
#   Parameters: 97,932
#
# GPU Memory after model init: 0.01 GB

# %%
# =============================================================================
# CELL 9: TensorFlow Wrapper for V2/V3 Compatibility
# =============================================================================

class TFGNNTATWrapper(tf.keras.Model):
    """
    TensorFlow wrapper for PyTorch GNN-TAT model.
    Allows using the same training infrastructure as V2/V3.
    """

    def __init__(self, pytorch_model: nn.Module, edge_index: torch.Tensor,
                 edge_weight: torch.Tensor, device: torch.device):
        super().__init__()

        self.pytorch_model = pytorch_model
        self.edge_index = edge_index
        self.edge_weight = edge_weight
        self.device = device

        # Placeholder for compatibility
        self._dummy_layer = tf.keras.layers.Dense(1)

    def call(self, inputs, training=False):
        """
        Forward pass with TensorFlow inputs.
        """
        # Convert TF tensor to numpy, then to PyTorch
        if isinstance(inputs, tf.Tensor):
            x_np = inputs.numpy()
        else:
            x_np = inputs

        x_torch = torch.tensor(x_np, dtype=torch.float32).to(self.device)

        # Set training mode
        if training:
            self.pytorch_model.train()
        else:
            self.pytorch_model.eval()

        # Forward pass
        with torch.set_grad_enabled(training):
            output = self.pytorch_model(x_torch, self.edge_index, self.edge_weight)

        # Convert back to TF tensor
        return tf.constant(output.detach().cpu().numpy())


def build_gnn_tat_model(n_features: int, n_lat: int, n_lon: int, horizon: int,
                        graph_builder: SpatialGraphBuilder, config: Dict,
                        edge_index: torch.Tensor, edge_weight: torch.Tensor,
                        device: torch.device) -> Tuple[nn.Module, TFGNNTATWrapper]:
    """
    Build GNN-TAT model and TF wrapper.

    Returns:
        pytorch_model: The PyTorch GNN-TAT model
        tf_wrapper: TensorFlow wrapper for compatibility
    """
    pytorch_model = GNN_TAT(
        n_features=n_features,
        n_nodes=graph_builder.n_nodes,
        n_lat=n_lat,
        n_lon=n_lon,
        horizon=horizon,
        config=config,
        gnn_chunk_size=config.get('gnn_chunk_size', 2)
    ).to(device)

    tf_wrapper = TFGNNTATWrapper(pytorch_model, edge_index, edge_weight, device)

    return pytorch_model, tf_wrapper


# Model registry (V2/V3 compatible format)
MODELS_V4_GNN = {
    'GNN_TAT_GAT': lambda n_feats, n_lat, n_lon, horizon: build_gnn_tat_model(
        n_feats, n_lat, n_lon, horizon, graph_builder,
        {**CONFIG, 'gnn_config': {**CONFIG['gnn_config'], 'gnn_type': 'GAT'}},
        edge_index_tensor, edge_weight_tensor, device
    ),
    'GNN_TAT_SAGE': lambda n_feats, n_lat, n_lon, horizon: build_gnn_tat_model(
        n_feats, n_lat, n_lon, horizon, graph_builder,
        {**CONFIG, 'gnn_config': {**CONFIG['gnn_config'], 'gnn_type': 'SAGE'}},
        edge_index_tensor, edge_weight_tensor, device
    ),
    'GNN_TAT_GCN': lambda n_feats, n_lat, n_lon, horizon: build_gnn_tat_model(
        n_feats, n_lat, n_lon, horizon, graph_builder,
        {**CONFIG, 'gnn_config': {**CONFIG['gnn_config'], 'gnn_type': 'GCN'}},
        edge_index_tensor, edge_weight_tensor, device
    ),
}

print(f"\nV4 GNN-TAT Models registered: {list(MODELS_V4_GNN.keys())}")
# Out:
# V4 GNN-TAT Models registered: ['GNN_TAT_GAT', 'GNN_TAT_SAGE', 'GNN_TAT_GCN']

# %% [markdown]
# ## 7. Training Infrastructure

# %%
# =============================================================================
# CELL 10: PyTorch Training Functions
# =============================================================================

def _fmt_hms(seconds: float) -> str:
    """Compact wall-clock formatting for progress lines."""
    s = int(max(seconds, 0))
    return f"{s // 3600:d}h{(s % 3600) // 60:02d}m{s % 60:02d}s"


class PrecipitationDataset(Dataset):
    """
    PyTorch Dataset for precipitation prediction.
    """

    def __init__(self, X: np.ndarray, y: np.ndarray):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


def train_pytorch_model(model: nn.Module, X_tr: np.ndarray, y_tr: np.ndarray,
                        X_va: np.ndarray, y_va: np.ndarray,
                        edge_index: torch.Tensor, edge_weight: torch.Tensor,
                        config: Dict, model_name: str, exp_name: str,
                        out_dir: Path, horizon: int, device: torch.device) -> Tuple[nn.Module, Dict]:
    """
    Train PyTorch GNN-TAT model.

    Returns:
        Trained model and training history
    """
    # Setup output directories
    metrics_dir = out_dir / f'h{horizon}' / exp_name / 'training_metrics'
    metrics_dir.mkdir(parents=True, exist_ok=True)
    model_path = metrics_dir / f"{model_name}_best_h{horizon}.pt"

    # ---------------------------------------------------------------- data placement
    # The training tensor is a few GB. On an 80 GB card it is cheaper to hold it
    # resident than to copy every batch across PCIe on every epoch; with 86 batches
    # and ~46 MB per batch that is ~4 GB of transfer per epoch, repeated 150 times.
    Xtr_t = torch.as_tensor(X_tr, dtype=torch.float32)
    ytr_t = torch.as_tensor(y_tr, dtype=torch.float32)
    Xva_t = torch.as_tensor(X_va, dtype=torch.float32)
    yva_t = torch.as_tensor(y_va, dtype=torch.float32)

    resident = False
    if config.get('gpu_resident_data', True) and device.type == 'cuda':
        need = sum(t.numel() * t.element_size() for t in (Xtr_t, ytr_t, Xva_t, yva_t))
        free_mem, _total_mem = torch.cuda.mem_get_info()
        # leave the majority of free memory for activations
        if need < 0.35 * free_mem:
            Xtr_t = Xtr_t.to(device); ytr_t = ytr_t.to(device)
            Xva_t = Xva_t.to(device); yva_t = yva_t.to(device)
            resident = True
        print(f"  Data: {need / 1e9:.2f} GB tensors, {free_mem / 1e9:.1f} GB free -> "
              f"{'GPU-resident' if resident else 'host, staged per batch'}")

    bs = config['batch_size']
    eval_bs = config.get('prediction_batch_size', bs)
    n_tr, n_va = Xtr_t.shape[0], Xva_t.shape[0]
    n_tr_batches = (n_tr + bs - 1) // bs
    n_va_batches = (n_va + eval_bs - 1) // eval_bs

    # ---------------------------------------------------------------- mixed precision
    use_amp = bool(config.get('use_amp', False)) and device.type == 'cuda'
    amp_dtype_name = config.get('amp_dtype', 'bf16')
    amp_dtype = torch.bfloat16 if amp_dtype_name == 'bf16' else torch.float16
    amp_scaler = torch.amp.GradScaler('cuda', enabled=(use_amp and amp_dtype is torch.float16))

    # Optimizer and scheduler
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=config['learning_rate'],
        weight_decay=config.get('weight_decay', 1e-5)
    )

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5,
        patience=config.get('lr_patience', config['patience'] // 2)
    )

    # Loss function
    criterion = nn.MSELoss()

    # Training tracking
    history = {
        'train_loss': [],
        'val_loss': [],
        'train_mae': [],
        'val_mae': [],
        'lr': [],
        'epoch_seconds': []
    }

    best_val_loss = float('inf')
    patience_counter = 0
    best_epoch = 0

    n_edges = int(edge_index.shape[1])
    print(f"\nTraining {model_name} on {exp_name}...")
    print(f"  Train batches: {n_tr_batches} (batch_size={bs}), Val batches: {n_va_batches} (batch_size={eval_bs})")
    print(f"  Graph: {n_edges:,} edges, {n_edges / max(model.n_nodes, 1):.0f} edges/node; "
          f"chunk {model.gnn_chunk_size}, checkpoint {model.use_grad_checkpoint}, amp {use_amp}")
    print(f"  Cost per step ~ batch_size x input_window x edges x layers = "
          f"{bs * config['input_window'] * n_edges * config['gnn_config']['num_gnn_layers'] / 1e9:.1f}G edge-messages")

    t_run_start = time.time()
    t_block = t_run_start
    epoch_seconds = []
    if device.type == 'cuda':
        torch.cuda.reset_peak_memory_stats()
    print(f"  Start: {datetime.now():%Y-%m-%d %H:%M:%S}")

    for epoch in range(config['epochs']):
        t_epoch = time.time()

        # Training phase
        model.train()
        tr_loss_sum = torch.zeros((), device=device)
        tr_mae_sum = torch.zeros((), device=device)
        perm = torch.randperm(n_tr)

        for bi in range(n_tr_batches):
            idx = perm[bi * bs:(bi + 1) * bs].to(Xtr_t.device)
            batch_X = Xtr_t[idx]
            batch_y = ytr_t[idx]
            if not resident:
                batch_X = batch_X.to(device, non_blocking=True)
                batch_y = batch_y.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            # Forward pass
            with torch.autocast('cuda', dtype=amp_dtype, enabled=use_amp):
                output = model(batch_X, edge_index, edge_weight)
                loss = criterion(output, batch_y)

            # Backward pass, gradient clipping, step
            if amp_scaler.is_enabled():
                amp_scaler.scale(loss).backward()
                amp_scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                amp_scaler.step(optimizer)
                amp_scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

            # Accumulate on device: one host sync per epoch instead of two per batch
            with torch.no_grad():
                tr_loss_sum += loss.detach().float()
                tr_mae_sum += F.l1_loss(output.detach().float(), batch_y.float())

        # Validation phase
        model.eval()
        va_loss_sum = torch.zeros((), device=device)
        va_mae_sum = torch.zeros((), device=device)

        with torch.no_grad():
            for bi in range(n_va_batches):
                batch_X = Xva_t[bi * eval_bs:(bi + 1) * eval_bs]
                batch_y = yva_t[bi * eval_bs:(bi + 1) * eval_bs]
                if not resident:
                    batch_X = batch_X.to(device, non_blocking=True)
                    batch_y = batch_y.to(device, non_blocking=True)

                with torch.autocast('cuda', dtype=amp_dtype, enabled=use_amp):
                    output = model(batch_X, edge_index, edge_weight)
                va_loss_sum += criterion(output.float(), batch_y).detach()
                va_mae_sum += F.l1_loss(output.detach().float(), batch_y)

        # Compute epoch metrics
        epoch_train_loss = float(tr_loss_sum.item()) / n_tr_batches
        epoch_train_mae = float(tr_mae_sum.item()) / n_tr_batches
        epoch_val_loss = float(va_loss_sum.item()) / n_va_batches
        epoch_val_mae = float(va_mae_sum.item()) / n_va_batches
        current_lr = optimizer.param_groups[0]['lr']
        epoch_seconds.append(time.time() - t_epoch)

        # Update history
        history['train_loss'].append(epoch_train_loss)
        history['val_loss'].append(epoch_val_loss)
        history['train_mae'].append(epoch_train_mae)
        history['val_mae'].append(epoch_val_mae)
        history['lr'].append(current_lr)
        history['epoch_seconds'].append(epoch_seconds[-1])

        # Learning rate scheduler
        scheduler.step(epoch_val_loss)

        # Early stopping check
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            best_epoch = epoch
            patience_counter = 0

            # Save best model
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': best_val_loss,
            }, model_path)
        else:
            patience_counter += 1

        # Print progress: every 10 epochs, with the wall clock for that block so the
        # cost of a configuration is visible while it runs rather than afterwards.
        if (epoch + 1) % 10 == 0 or epoch == 0:
            now = time.time()
            n_since = len(epoch_seconds) if epoch == 0 else min(10, len(epoch_seconds))
            per_ep = (now - t_block) / n_since
            t_block = now
            eta = per_ep * (config['epochs'] - epoch - 1)
            peak = torch.cuda.max_memory_allocated() / 1e9 if device.type == 'cuda' else 0.0
            print(f"  Epoch {epoch+1:3d}/{config['epochs']}: "
                  f"train_loss={epoch_train_loss:.4f}, val_loss={epoch_val_loss:.4f}, "
                  f"MAE={epoch_val_mae:.4f}, lr={current_lr:.2e} | "
                  f"{per_ep:6.1f}s/ep {per_ep / n_tr_batches:5.2f}s/batch  "
                  f"elapsed {_fmt_hms(now - t_run_start)}  ETA {_fmt_hms(eta)}  "
                  f"peak {peak:.1f}GB  {datetime.now():%H:%M:%S}")

        # Early stopping
        if patience_counter >= config['patience']:
            print(f"  Early stopping at epoch {epoch+1}")
            break

    # Load best model
    checkpoint = torch.load(model_path, weights_only=False)
    model.load_state_dict(checkpoint['model_state_dict'])

    # Save training history
    history_df = pd.DataFrame(history)
    history_df.to_csv(metrics_dir / f"{model_name}_training_log_h{horizon}.csv", index=False)

    # Save summary
    summary = {
        'model_name': model_name,
        'experiment': exp_name,
        'horizon': horizon,
        'best_epoch': best_epoch + 1,
        'best_val_loss': float(best_val_loss),
        'final_train_loss': float(history['train_loss'][-1]),
        'final_val_loss': float(history['val_loss'][-1]),
        'total_epochs': len(history['train_loss']),
        'parameters': sum(p.numel() for p in model.parameters()),
        # Measured compute cost. The manuscript's compute table is populated from
        # these fields rather than from a remembered figure.
        'wall_seconds': float(time.time() - t_run_start),
        'sec_per_epoch_mean': float(np.mean(epoch_seconds)),
        'peak_gpu_gb': float(torch.cuda.max_memory_allocated() / 1e9) if device.type == 'cuda' else None,
        'device_name': torch.cuda.get_device_name(0) if device.type == 'cuda' else 'cpu',
        'batch_size': bs,
        'gnn_chunk_size': int(model.gnn_chunk_size),
        'grad_checkpoint': bool(model.use_grad_checkpoint),
        'amp': amp_dtype_name if use_amp else 'fp32',
        'tf32': bool(torch.backends.cuda.matmul.allow_tf32) if device.type == 'cuda' else False,
        'n_edges': n_edges
    }

    with open(metrics_dir / f"{model_name}_history.json", 'w') as f:
        json.dump(summary, f, indent=2)

    print(f"  Training complete. Best val_loss: {best_val_loss:.4f} at epoch {best_epoch+1} "
          f"in {_fmt_hms(time.time() - t_run_start)} "
          f"({np.mean(epoch_seconds):.1f}s/epoch, peak "
          f"{torch.cuda.max_memory_allocated() / 1e9 if device.type == 'cuda' else 0.0:.1f}GB)")

    # Free the resident copies before the next configuration is built.
    del Xtr_t, ytr_t, Xva_t, yva_t
    if hasattr(model, 'clear_edge_cache'):
        model.clear_edge_cache()
    if device.type == 'cuda':
        torch.cuda.empty_cache()

    return model, summary

# %%
# =============================================================================
# CELL 11: Evaluation Functions (V2/V3 Compatible)
# =============================================================================

def evaluate_model(model: nn.Module, X_va: np.ndarray, y_va: np.ndarray,
                   edge_index: torch.Tensor, edge_weight: torch.Tensor,
                   scaler: StandardScaler, device: torch.device,
                   model_name: str, exp_name: str, horizon: int) -> List[Dict]:
    """
    Evaluate model and compute metrics per horizon step.

    Returns:
        List of metric dictionaries (one per horizon step)
    """
    model.eval()
    results = []

    # Predict in batches. Inference builds no autograd graph, so this can be
    # larger than the training batch size.
    batch_size = CONFIG.get('prediction_batch_size', 4)
    predictions = []

    with torch.no_grad():
        for i in range(0, len(X_va), batch_size):
            batch_X = torch.tensor(X_va[i:i+batch_size], dtype=torch.float32).to(device)
            batch_pred = model(batch_X, edge_index, edge_weight)
            predictions.append(batch_pred.cpu().numpy())

    y_hat_sc = np.concatenate(predictions, axis=0)

    # Inverse transform predictions
    y_hat = scaler.inverse_transform(y_hat_sc.reshape(-1, 1)).reshape(y_hat_sc.shape)
    y_true = scaler.inverse_transform(y_va.reshape(-1, 1)).reshape(y_va.shape)

    # Compute metrics per horizon step
    for h in range(horizon):
        y_h_true = y_true[:, h].flatten()
        y_h_pred = y_hat[:, h].flatten()

        # Metrics
        rmse = np.sqrt(np.mean((y_h_pred - y_h_true) ** 2))
        mae = np.mean(np.abs(y_h_pred - y_h_true))

        ss_res = np.sum((y_h_true - y_h_pred) ** 2)
        ss_tot = np.sum((y_h_true - np.mean(y_h_true)) ** 2)
        r2 = 1 - (ss_res / (ss_tot + 1e-8))

        results.append({
            'TotalHorizon': horizon,
            'Experiment': exp_name,
            'Model': model_name,
            'H': h + 1,
            'RMSE': rmse,
            'MAE': mae,
            'R^2': r2,
            'Mean_True_mm': np.mean(y_h_true),
            'Mean_Pred_mm': np.mean(y_h_pred),
            'TotalPrecipitation': np.sum(y_h_true),
            'TotalPrecipitation_Pred': np.sum(y_h_pred)
        })

    return results, y_hat, y_true

# %% [markdown]
# ## 8. Main Training Loop

# %%
# ==================================================
# LEGACY -> SEED42 MIGRATION HELPER  (run once, manually)
# ==================================================
# Copies legacy non-seed-scoped v4 outputs (seed=42 era) into SEED42/ paths
# so the consolidation cell can read uniformly from SEED*/.
# This is a COPY operation: originals are never modified or deleted.
#
# Usage:
#   migrate_legacy_to_seed42_v4(dry_run=True)   # preview what would be copied
#   migrate_legacy_to_seed42_v4(dry_run=False)  # actually copy

def migrate_legacy_to_seed42_v4(dry_run=True):
    """Copy legacy v4 outputs to SEED42/ subtree.

    Sources (legacy, non-scoped):
      - {out_root}/map_exports/**
      - {out_root}/h{H}/**
      - {out_root}/metrics_spatial_v4_gnn_tat_*.csv

    Targets:
      - {out_root}/SEED42/map_exports/**
      - {out_root}/SEED42/h{H}/**
      - {out_root}/SEED42/metrics_spatial_v4_gnn_tat_*.csv
    """
    from pathlib import Path
    import shutil

    out_root = Path(CONFIG['out_root'])
    if not out_root.exists():
        print(f"[MIGRATE v4] out_root does not exist: {out_root}")
        return

    sources = []
    # map_exports/
    src_map = out_root / 'map_exports'
    if src_map.exists():
        for p in src_map.rglob('*'):
            if p.is_file():
                sources.append(('map_exports', p, p.relative_to(src_map)))
    # h{H}/ directories
    for h_dir in out_root.glob('h[0-9]*'):
        if h_dir.is_dir():
            for p in h_dir.rglob('*'):
                if p.is_file():
                    sources.append(('h_dir', p, p.relative_to(out_root)))
    # Top-level CSVs (metrics_spatial_v4_gnn_tat_*.csv)
    for p in out_root.glob('metrics_spatial_v4_gnn_tat_*.csv'):
        if p.is_file():
            sources.append(('csv', p, p.name))

    if not sources:
        print(f"[MIGRATE v4] No legacy artifacts found under {out_root}")
        return

    copied = 0
    skipped = 0
    dst_root = out_root / 'SEED42'

    for kind, src, rel in sources:
        if kind == 'map_exports':
            dst = dst_root / 'map_exports' / rel
        elif kind == 'h_dir':
            dst = dst_root / rel
        else:  # csv
            dst = dst_root / rel

        if dst.exists() and dst.stat().st_size == src.stat().st_size:
            skipped += 1
            continue

        rel_src = src.relative_to(out_root)
        rel_dst = dst.relative_to(dst_root)
        if dry_run:
            print(f"[DRY]  {rel_src} -> SEED42/{rel_dst}")
        else:
            dst.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(src, dst)
            print(f"[COPY] {rel_src} -> SEED42/{rel_dst}")
        copied += 1

    verb = "would copy" if dry_run else "copied"
    print("")
    print(f"[MIGRATE v4] {verb} {copied} files, skipped {skipped} (already present).")
    if dry_run:
        print("[MIGRATE v4] Call with dry_run=False to actually copy.")


print("[MIGRATE v4] Helper defined. To run:")
print("    migrate_legacy_to_seed42_v4(dry_run=True)   # preview")
print("    migrate_legacy_to_seed42_v4(dry_run=False)  # execute")
# Out:
# [MIGRATE v4] Helper defined. To run:
#     migrate_legacy_to_seed42_v4(dry_run=True)   # preview
#     migrate_legacy_to_seed42_v4(dry_run=False)  # execute

# %%
# =============================================================================
# CELL 12: Main Training Loop (V2/V3 Compatible) - IMPROVED
# =============================================================================
# Changes: Better memory management between experiments
#          Multi-seed wrapping (see Cell A for MULTI_SEED config)

# Results collection by seed
all_results_by_seed = {}
all_histories_by_seed = {}
all_predictions_by_seed = {}

# Fix (adversarial review #3): Initialize downstream globals so cells after SKIP_EXISTING don't raise NameError.
res_df = None
all_results = []
all_histories = {}
all_predictions = {}
horizon_label = 'multi' if len(CONFIG['enabled_horizons']) > 1 else str(CONFIG['enabled_horizons'][0])

for current_seed in _resolve_seeds():
    CURRENT_SEED = current_seed
    seed_out_root = get_seed_scoped_path(current_seed, CONFIG['out_root'])
    seed_out_root.mkdir(parents=True, exist_ok=True)
    if MULTI_SEED:
        print("")
        print("=" * 60)
        print(f">>> TRAINING SEED = {current_seed} (out_root={seed_out_root}) <<<")
        print("=" * 60)
        _apply_seeds_v4(current_seed)

    all_results = []
    all_histories = {}
    all_predictions = {}

    for horizon in CONFIG['enabled_horizons']:
        print("")
        print("=" * 60)
        print(f"Running experiments for horizon H={horizon} months")
        print("=" * 60)

        # Preprocess data for this horizon
        data_splits_h = preprocess_data(ds, CONFIG, lat, lon, horizon)

        # PATCH: factorial (enabled_variants x enabled_features)
        _enabled_features = CONFIG.get('enabled_features', list(CONFIG['feature_sets'].keys()))
        for exp_name in CONFIG['feature_sets'].keys():
            if exp_name not in _enabled_features:
                print(f"  [SKIP feature] {exp_name} not in enabled_features={_enabled_features}")
                continue
            if exp_name not in data_splits_h:
                print("")
                print(f"Skipping {exp_name}: data not available")
                continue

            print("")
            print(f"--- Experiment: {exp_name} ---")

            X_tr, y_tr, X_va, y_va, scaler = data_splits_h[exp_name]
            n_features = X_tr.shape[-1]

            # Config-driven variant iteration (replaces former PAPER 5 FILTER).
            _enabled_variants = CONFIG.get('enabled_variants', ['GAT'])
            _variant_models = [f'GNN_TAT_{v}' for v in _enabled_variants]
            for model_name in _variant_models:
                if SKIP_EXISTING and is_seed_output_complete(current_seed, horizon, exp_name, model_name):
                    print(f'[SKIP] seed={current_seed} H={horizon} exp={exp_name} model={model_name}')
                    continue

                print("")
                print(f">>> Model: {model_name}")

                # Clear memory BEFORE creating new model
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()
                gc.collect()

                try:
                    # Build model
                    gnn_type = model_name.split('_')[-1]  # GAT, SAGE, or GCN
                    model_config = {**CONFIG, 'gnn_config': {**CONFIG['gnn_config'], 'gnn_type': gnn_type}}

                    model = GNN_TAT(
                        n_features=n_features,
                        n_nodes=graph_builder.n_nodes,
                        n_lat=lat,
                        n_lon=lon,
                        horizon=horizon,
                        config=model_config,
                        gnn_chunk_size=model_config.get('gnn_chunk_size', 2)
                    ).to(device)

                    # Train
                    model, history = train_pytorch_model(
                        model, X_tr, y_tr, X_va, y_va,
                        edge_index_tensor, edge_weight_tensor,
                        CONFIG, model_name, exp_name,
                        seed_out_root, horizon, device
                    )

                    all_histories[f"{exp_name}_{model_name}_H{horizon}"] = history

                    # Evaluate
                    results, y_hat, y_true = evaluate_model(
                        model, X_va, y_va,
                        edge_index_tensor, edge_weight_tensor,
                        scaler, device,
                        model_name, exp_name, horizon
                    )

                    all_results.extend(results)
                    all_predictions[f"{exp_name}_{model_name}_H{horizon}"] = {
                        'y_hat': y_hat,
                        'y_true': y_true
                    }

                    # Print summary metrics
                    avg_rmse = np.mean([r['RMSE'] for r in results])
                    avg_mae = np.mean([r['MAE'] for r in results])
                    avg_r2 = np.mean([r['R^2'] for r in results])
                    print(f"  Results: RMSE={avg_rmse:.2f}mm, MAE={avg_mae:.2f}mm, R2={avg_r2:.3f}")

                except Exception as e:
                    print(f"  ERROR: {e}")
                    import traceback
                    traceback.print_exc()

                finally:
                    # ALWAYS cleanup after each model
                    if 'model' in dir():
                        del model
                    if torch.cuda.is_available():
                        torch.cuda.empty_cache()
                    gc.collect()

            # Cleanup after each experiment
            del X_tr, y_tr, X_va, y_va
            gc.collect()

        # Cleanup after each horizon
        del data_splits_h
        gc.collect()

    # Collect results for this seed
    all_results_by_seed[current_seed] = all_results
    all_histories_by_seed[current_seed] = all_histories
    all_predictions_by_seed[current_seed] = all_predictions

print("")
print("=" * 60)
print("Training complete (all seeds)!")
_total_experiments = sum(len(r) for r in all_results_by_seed.values())
print(f"Total result rows across seeds: {_total_experiments}")
for _seed, _results in all_results_by_seed.items():
    _n_exps = len(_results) // CONFIG['horizon'] if _results else 0
    print(f"  seed={_seed}: {_n_exps} experiments, {len(_results)} rows")
print("=" * 60)
# Out:
# ...
# >>> TRAINING SEED = 456 (out_root=/content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/SEED456) <<<
# ...
#
# ...
# Running experiments for horizon H=12 months
# ...
#
# Processing experiment: BASIC
#   X shape: (518, 61, 65, 12)
#   y shape: (518, 61, 65)
#   Train windows: 343, Val windows: 33
#   Final shapes: X_tr=(343, 60, 61, 65, 12), y_tr=(343, 12, 61, 65, 1)
#                 X_va=(33, 60, 61, 65, 12), y_va=(33, 12, 61, 65, 1)
#
# Processing experiment: KCE
#   X shape: (518, 61, 65, 15)
#   y shape: (518, 61, 65)
#   Train windows: 343, Val windows: 33
#   Final shapes: X_tr=(343, 60, 61, 65, 15), y_tr=(343, 12, 61, 65, 1)
#                 X_va=(33, 60, 61, 65, 15), y_va=(33, 12, 61, 65, 1)
#
# Processing experiment: PAFC
#   X shape: (518, 61, 65, 18)
#   y shape: (518, 61, 65)
#   Train windows: 343, Val windows: 33
#   Final shapes: X_tr=(343, 60, 61, 65, 18), y_tr=(343, 12, 61, 65, 1)
#                 X_va=(33, 60, 61, 65, 18), y_va=(33, 12, 61, 65, 1)
# ...

# %% [markdown]
# ## 9. Results Export and Visualization

# %%
# =============================================================================
# CELL 13: Save Results (V2/V3 Compatible Format) - Multi-Seed Aware
# =============================================================================

# Iterate over seeds collected by the training loop. When MULTI_SEED=False there
# is exactly one entry (LEGACY_SEED=42); when MULTI_SEED=True, one entry per seed.
_all_results_combined = []

for current_seed, seed_results in all_results_by_seed.items():
    CURRENT_SEED = current_seed

    if not seed_results:
        print(f"[seed={current_seed}] No results to save.")
        continue

    # Create per-seed results DataFrame
    res_df = pd.DataFrame(seed_results)

    # Add bias metrics
    res_df['mean_bias_mm'] = res_df['Mean_Pred_mm'] - res_df['Mean_True_mm']
    res_df['mean_bias_pct'] = 100 * res_df['mean_bias_mm'] / (res_df['Mean_True_mm'].replace(0, np.nan))

    # Save to seed-scoped CSV
    horizon_label = 'multi' if len(CONFIG['enabled_horizons']) > 1 else str(CONFIG['enabled_horizons'][0])
    out_csv = _seed_out_root() / f'metrics_spatial_v4_gnn_tat_h{horizon_label}.csv'
    out_csv.parent.mkdir(parents=True, exist_ok=True)
    res_df.to_csv(out_csv, index=False)

    print(f"[seed={current_seed}] Results saved to: {out_csv}")
    print(f"[seed={current_seed}] Summary:")
    print(res_df.groupby(['Model', 'Experiment'])[['RMSE', 'MAE', 'R^2']].mean().round(3))

    # Retain the last-seed DataFrame as `res_df` for downstream cells (summary cell
    # below uses `res_df` directly). Also collect for combined view.
    _all_results_combined.extend(seed_results)

# Keep legacy names alive for downstream cells
if _all_results_combined:
    all_results = _all_results_combined  # backward-compat: summary cell uses this
# Out:
# [seed=456] Results saved to: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/SEED456/metrics_spatial_v4_gnn_tat_h12.csv
# [seed=456] Summary:
#                               RMSE        MAE    R^2
# Model        Experiment
# GNN_TAT_GAT  PAFC        93.113998  66.263000  0.508
# GNN_TAT_GCN  PAFC        89.281998  65.141998  0.548
# GNN_TAT_SAGE PAFC        82.543999  58.056999  0.613

# %%
# =============================================================================
# CELL 14: Visualization - Model Comparison
# =============================================================================

def plot_model_comparison(res_df: pd.DataFrame, output_dir: Path):
    """
    Plot model comparison charts.
    """
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # 1. RMSE by Model and Experiment
    ax1 = axes[0, 0]
    pivot_rmse = res_df.groupby(['Model', 'Experiment'])['RMSE'].mean().unstack()
    pivot_rmse.plot(kind='bar', ax=ax1, width=0.8)
    ax1.set_ylabel('RMSE (mm)')
    ax1.set_title('RMSE by Model and Feature Set')
    ax1.legend(title='Feature Set')
    ax1.tick_params(axis='x', rotation=45)

    # 2. R² by Model and Experiment
    ax2 = axes[0, 1]
    pivot_r2 = res_df.groupby(['Model', 'Experiment'])['R^2'].mean().unstack()
    pivot_r2.plot(kind='bar', ax=ax2, width=0.8)
    ax2.set_ylabel('R²')
    ax2.set_title('R² by Model and Feature Set')
    ax2.legend(title='Feature Set')
    ax2.tick_params(axis='x', rotation=45)
    ax2.axhline(y=0.437, color='red', linestyle='--', label='V2 Baseline (0.437)')

    # 3. RMSE by Horizon
    ax3 = axes[1, 0]
    for model in res_df['Model'].unique():
        model_data = res_df[res_df['Model'] == model]
        for exp in model_data['Experiment'].unique():
            exp_data = model_data[model_data['Experiment'] == exp]
            ax3.plot(exp_data['H'], exp_data['RMSE'],
                    marker='o', label=f"{model} ({exp})")
    ax3.set_xlabel('Horizon (H)')
    ax3.set_ylabel('RMSE (mm)')
    ax3.set_title('RMSE Degradation by Horizon')
    ax3.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    ax3.grid(True, alpha=0.3)

    # 4. Bias Distribution
    ax4 = axes[1, 1]
    for model in res_df['Model'].unique():
        model_bias = res_df[res_df['Model'] == model]['mean_bias_mm']
        ax4.hist(model_bias, bins=20, alpha=0.5, label=model)
    ax4.axvline(x=0, color='red', linestyle='--')
    ax4.set_xlabel('Mean Bias (mm)')
    ax4.set_ylabel('Frequency')
    ax4.set_title('Bias Distribution by Model')
    ax4.legend()

    plt.tight_layout()

    # Save
    fig_path = output_dir / 'model_comparison_v4_gnn_tat.png'
    plt.savefig(fig_path, dpi=150, bbox_inches='tight')
    print(f"Comparison plot saved to: {fig_path}")

    plt.show()


if len(all_results) > 0:
    plot_model_comparison(res_df, CONFIG['out_root'])
else:
    print("No results to plot")
# Out:
# Comparison plot saved to: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/model_comparison_v4_gnn_tat.png

# %%
# =============================================================================
# CELL 15: Graph Edge Analysis (GNN Interpretability)
# =============================================================================

def analyze_graph_edges(graph_builder: SpatialGraphBuilder, edge_index: np.ndarray,
                        edge_weight: np.ndarray, output_dir: Path):
    """
    Analyze and visualize graph edges for interpretability.
    """
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    # 1. Edge weight heatmap (adjacency matrix)
    ax1 = axes[0]

    # Reconstruct adjacency matrix
    adj_matrix = np.zeros((graph_builder.n_nodes, graph_builder.n_nodes))
    for idx in range(len(edge_weight)):
        i, j = edge_index[0, idx], edge_index[1, idx]
        adj_matrix[i, j] = edge_weight[idx]

    im1 = ax1.imshow(adj_matrix, cmap='YlOrRd', aspect='auto')
    plt.colorbar(im1, ax=ax1, label='Edge Weight')
    ax1.set_xlabel('Node Index')
    ax1.set_ylabel('Node Index')
    ax1.set_title('Adjacency Matrix (Edge Weights)')

    # 2. Strongest edges by location
    ax2 = axes[1]

    # Get top 10% strongest edges
    threshold = np.percentile(edge_weight, 90)
    strong_edges = edge_weight > threshold

    pos = graph_builder.node_positions

    # Draw all nodes
    scatter = ax2.scatter(pos[:, 1], pos[:, 0], c=graph_builder.node_elevations,
                         cmap='terrain', s=100, edgecolors='black', linewidth=0.5,
                         zorder=2)
    plt.colorbar(scatter, ax=ax2, label='Elevation (m)')

    # Draw strong edges
    for idx in np.where(strong_edges)[0]:
        i, j = edge_index[0, idx], edge_index[1, idx]
        ax2.plot([pos[i, 1], pos[j, 1]], [pos[i, 0], pos[j, 0]],
                'r-', alpha=0.6, linewidth=edge_weight[idx] * 2, zorder=1)

    ax2.set_xlabel('Longitude')
    ax2.set_ylabel('Latitude')
    ax2.set_title(f'Top 10% Strongest Edges (n={strong_edges.sum()})')

    plt.tight_layout()

    # Save
    fig_path = output_dir / 'graph_edge_analysis.png'
    plt.savefig(fig_path, dpi=150, bbox_inches='tight')
    print(f"Edge analysis saved to: {fig_path}")

    plt.show()

    # Print statistics
    print(f"\nGraph Statistics:")
    print(f"  Total nodes: {graph_builder.n_nodes}")
    print(f"  Total edges: {len(edge_weight)}")
    print(f"  Average edge weight: {np.mean(edge_weight):.4f}")
    print(f"  Max edge weight: {np.max(edge_weight):.4f}")
    print(f"  Strong edges (top 10%): {strong_edges.sum()}")


analyze_graph_edges(graph_builder, edge_index, edge_weight, CONFIG['out_root'])
# Out:
# Edge analysis saved to: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/graph_edge_analysis.png
# Graph Statistics:
#   Total nodes: 3965
#   Total edges: 500000
#   Average edge weight: 0.4912
#   Max edge weight: 1.0000
#   Strong edges (top 10%): 50000

# %%
# =============================================================================
# CELL 16: Export Predictions for Map Generation - Multi-Seed Aware
# =============================================================================

def export_predictions(predictions_dict: Dict, output_dir: Path, horizon: int):
    """
    Export predictions for map generation (V2/V3 compatible format).
    """
    map_out_root = output_dir / 'map_exports'

    for key, data in predictions_dict.items():
        parts = key.split('_')
        exp_name = parts[0]
        model_name = '_'.join(parts[1:-1])

        export_dir = map_out_root / f'H{horizon}' / exp_name / model_name
        export_dir.mkdir(parents=True, exist_ok=True)

        # Save arrays
        np.save(export_dir / 'predictions.npy', data['y_hat'])
        np.save(export_dir / 'targets.npy', data['y_true'])

        # Save metadata
        metadata = {
            'model': model_name,
            'experiment': exp_name,
            'horizon': horizon,
            'generated_at': datetime.now().isoformat(),
            'shape': list(data['y_hat'].shape),
            'rmse_mean': float(np.sqrt(np.mean((data['y_hat'] - data['y_true'])**2))),
            'framework': 'GNN-TAT V4'
        }

        with open(export_dir / 'metadata.json', 'w') as f:
            json.dump(metadata, f, indent=2)

        print(f"Exported: {key}")

    print("")
    print(f"All predictions exported to: {map_out_root}")


# Multi-seed wrapper: iterate and re-scope output path for each seed
if all_predictions_by_seed:
    for current_seed, seed_predictions in all_predictions_by_seed.items():
        CURRENT_SEED = current_seed
        if len(seed_predictions) > 0:
            if MULTI_SEED:
                print("")
                print(f">>> EXPORTING PREDICTIONS for seed={current_seed} <<<")
            export_predictions(seed_predictions, _seed_out_root(), CONFIG['horizon'])
# Out:
# >>> EXPORTING PREDICTIONS for seed=456 <<<
# Exported: PAFC_GNN_TAT_GAT_H12
# Exported: PAFC_GNN_TAT_GCN_H12
# Exported: PAFC_GNN_TAT_SAGE_H12
#
# All predictions exported to: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/SEED456/map_exports

# %% [markdown]
# ## 10. Summary and Next Steps

# %%
# =============================================================================
# CELL 17: Final Summary
# =============================================================================

print("="*60)
print("V4 GNN-TAT Training Complete")
print("="*60)

if len(all_results) > 0:
    # Summary statistics
    summary_df = res_df.groupby(['Model', 'Experiment']).agg({
        'RMSE': ['mean', 'std'],
        'MAE': ['mean', 'std'],
        'R^2': ['mean', 'std'],
        'mean_bias_mm': 'mean'
    }).round(3)

    print("\nPerformance Summary:")
    print(summary_df)

    # Best model
    best_idx = res_df.groupby(['Model', 'Experiment'])['R^2'].mean().idxmax()
    best_model, best_exp = best_idx
    best_r2 = res_df.groupby(['Model', 'Experiment'])['R^2'].mean().max()
    best_rmse = res_df[(res_df['Model'] == best_model) & (res_df['Experiment'] == best_exp)]['RMSE'].mean()

    print(f"\nBest Model: {best_model} with {best_exp} features")
    print(f"  R²: {best_r2:.3f}")
    print(f"  RMSE: {best_rmse:.2f} mm")

    # Comparison with V2 baseline
    v2_baseline_r2 = 0.437
    v2_baseline_rmse = 98.17

    r2_improvement = (best_r2 - v2_baseline_r2) / v2_baseline_r2 * 100
    rmse_improvement = (v2_baseline_rmse - best_rmse) / v2_baseline_rmse * 100

    print(f"\nComparison with V2 ConvLSTM Baseline:")
    print(f"  V2 Baseline: R²={v2_baseline_r2:.3f}, RMSE={v2_baseline_rmse:.2f}mm")
    print(f"  V4 GNN-TAT:  R²={best_r2:.3f}, RMSE={best_rmse:.2f}mm")
    print(f"  Improvement: R² {r2_improvement:+.1f}%, RMSE {rmse_improvement:+.1f}%")

print("\n" + "="*60)
print("Output Files:")
print(f"  Metrics CSV: {CONFIG['out_root'] / f'metrics_spatial_v4_gnn_tat_h{horizon_label}.csv'}")
print(f"  Visualizations: {CONFIG['out_root']}")
print(f"  Predictions: {CONFIG['out_root'] / 'map_exports'}")
print("="*60)
# Out:
# ...
# V4 GNN-TAT Training Complete
# ...
#
# Performance Summary:
#                               RMSE               MAE           R^2         \
#                               mean    std       mean    std   mean    std
# Model        Experiment
# GNN_TAT_GAT  PAFC        93.113998  2.959  66.263000  2.617  0.508  0.028
# GNN_TAT_GCN  PAFC        89.281998  2.751  65.141998  2.572  0.548  0.026
# GNN_TAT_SAGE PAFC        82.543999  3.563  58.056999  2.498  0.613  0.030
#
#                         mean_bias_mm
#                                 mean
# Model        Experiment
# GNN_TAT_GAT  PAFC         -34.541000
# GNN_TAT_GCN  PAFC         -20.927999
# GNN_TAT_SAGE PAFC         -30.701000
#
# Best Model: GNN_TAT_SAGE with PAFC features
#   R²: 0.613
#   RMSE: 82.54 mm
#
# Comparison with V2 ConvLSTM Baseline:
#   V2 Baseline: R²=0.437, RMSE=98.17mm
#   V4 GNN-TAT:  R²=0.613, RMSE=82.54mm
#   Improvement: R² +40.4%, RMSE +15.9%
#
# ...
# Output Files:
# ...

# %%
# ==================================================
# MULTI-SEED CONSOLIDATION  (run after all seed runs complete)
# ==================================================
# Reads per-seed metrics CSVs from SEED*/ subdirectories (and legacy non-scoped
# CSVs at the root) and produces a consolidated table with mean/std across seeds.
# Output: {CONFIG["out_root"]}/metrics_multiseed_consolidated.csv

def consolidate_v4_multiseed():
    """Walk CONFIG['out_root'] for seed-scoped and legacy metric CSVs,
    compute mean/std per (Experiment, Model, H), and save consolidated CSV.
    """
    from pathlib import Path
    import pandas as pd
    import numpy as np

    out_root = Path(CONFIG['out_root'])
    if not out_root.exists():
        print(f"[CONSOLIDATE v4] out_root does not exist: {out_root}")
        return None

    # Discover seed sources
    seed_frames = []

    # Legacy (non-scoped) CSVs at the root - treated as seed=LEGACY_SEED
    # Fix (adversarial review #1): Skip loading legacy root CSVs if SEED42/ exists
    # (migration copies legacy -> SEED42/, so loading both would double-count).
    legacy_csvs = list(out_root.glob('metrics_spatial_v4_gnn_tat_*.csv'))
    if (out_root / 'SEED42').exists():
        print('[CONSOLIDATE v4] SEED42/ present; skipping legacy root CSVs to avoid double-counting.')
        legacy_csvs = []
    legacy_csvs = [p for p in legacy_csvs if 'multiseed_consolidated' not in p.name]
    for csv in legacy_csvs:
        df = pd.read_csv(csv)
        df['_seed'] = LEGACY_SEED
        df['_source'] = 'legacy'
        seed_frames.append(df)
        print(f"[CONSOLIDATE v4] Loaded legacy: {csv.name} ({len(df)} rows)")

    # SEED{n}/ scoped CSVs
    for seed_dir in sorted(out_root.glob('SEED*')):
        if not seed_dir.is_dir():
            continue
        try:
            seed_val = int(seed_dir.name[4:])
        except ValueError:
            continue
        csvs = list(seed_dir.glob('metrics_spatial_v4_gnn_tat_*.csv'))
        csvs = [p for p in csvs if 'multiseed_consolidated' not in p.name]
        for csv in csvs:
            df = pd.read_csv(csv)
            df['_seed'] = seed_val
            df['_source'] = seed_dir.name
            seed_frames.append(df)
            print(f"[CONSOLIDATE v4] Loaded {seed_dir.name}: {csv.name} ({len(df)} rows)")

    if not seed_frames:
        print(f"[CONSOLIDATE v4] No metric CSVs found under {out_root}")
        return None

    all_df = pd.concat(seed_frames, ignore_index=True)
    print(f"[CONSOLIDATE v4] Total rows across all seeds: {len(all_df)}")
    print(f"[CONSOLIDATE v4] Unique seeds: {sorted(all_df['_seed'].unique().tolist())}")

    # Group by (Experiment, Model, H), compute mean/std/count for metric cols
    group_cols = [c for c in ['TotalHorizon', 'Experiment', 'Model', 'H'] if c in all_df.columns]
    metric_cols = [c for c in ['RMSE', 'MAE', 'R^2', 'Mean_True_mm', 'Mean_Pred_mm',
                                'mean_bias_mm', 'mean_bias_pct',
                                'TotalPrecipitation', 'TotalPrecipitation_Pred']
                   if c in all_df.columns]

    if not group_cols or not metric_cols:
        print(f"[CONSOLIDATE v4] Unexpected CSV schema. Columns: {list(all_df.columns)}")
        return all_df

    agg = all_df.groupby(group_cols)[metric_cols].agg(['mean', 'std', 'count'])
    agg.columns = [f'{m}_{stat}' for m, stat in agg.columns]
    agg = agg.reset_index()

    rename_map = {c: c.replace('_count', '_n_seeds') for c in agg.columns if c.endswith('_count')}
    agg = agg.rename(columns=rename_map)

    # Record which seeds contributed per (Experiment, Model, H)
    def _seeds_for_row(row):
        mask = True
        for col in group_cols:
            mask = mask & (all_df[col] == row[col])
        seeds = sorted(all_df.loc[mask, '_seed'].unique().tolist())
        return ','.join(str(s) for s in seeds)
    agg['seeds_used'] = agg.apply(_seeds_for_row, axis=1)

    out_csv = out_root / 'metrics_multiseed_consolidated.csv'
    agg.to_csv(out_csv, index=False)
    print("")
    print(f"[CONSOLIDATE v4] Consolidated metrics saved to: {out_csv}")
    print(f"[CONSOLIDATE v4] Rows: {len(agg)}")

    try:
        import IPython.display as ipd
        ipd.display(agg)
    except Exception:
        print(agg.to_string(max_rows=30, max_cols=10))

    return agg


print("[CONSOLIDATE v4] Helper defined. To execute:")
print("    df = consolidate_v4_multiseed()")
print("    df  # Displays the consolidated table")
# Out:
# [CONSOLIDATE v4] Helper defined. To execute:
#     df = consolidate_v4_multiseed()
#     df  # Displays the consolidated table

# %%
# =============================================================================
# CELL 18: Save Notebook State
# =============================================================================

# Save complete state for reproducibility
state = {
    'config': {k: str(v) if isinstance(v, Path) else v for k, v in CONFIG.items() if k != 'feature_sets'},
    'feature_sets': CONFIG['feature_sets'],
    'gnn_config': CONFIG['gnn_config'],
    'grid_info': {
        'lat': lat,
        'lon': lon,
        'n_nodes': graph_builder.n_nodes,
        'n_edges': len(edge_weight)
    },
    'training_summaries': all_histories,
    'timestamp': datetime.now().isoformat()
}

state_path = CONFIG['out_root'] / 'experiment_state_v4.json'
with open(state_path, 'w') as f:
    json.dump(state, f, indent=2, default=str)

print(f"Experiment state saved to: {state_path}")
print("\nV4 GNN-TAT notebook execution complete.")
# Out:
# Experiment state saved to: /content/drive/MyDrive/ml_precipitation_prediction/models/output/V4_GNN_TAT_Models_p30/experiment_state_v4.json
#
# V4 GNN-TAT notebook execution complete.
